# %% [markdown]
# <a href="https://colab.research.google.com/github/comaraDOTcom/machine-vision/blob/main/deep-learning/Etivity_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Etivity 2
# Name: Conor O'Mara
# Student number: 20151845

# %% [markdown]
# # Etivity 2: Deep Convolutional Neural Network on CIFAR-10 Dataset
#
# In this assignment, we will gain some practical experience of coding a deep convolutional neural network in Tensorflow. The simplest way to code a network is to use the High level Keras API within Tensorflow 2.5.
#
# ## (a) Introduction
#
#  In this assignment to reduce training time and computation, we will train our network using the simple [CIFAR10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset.
# ![link text](https://paperswithcode.com/media/datasets/CIFAR-10-0000000431-b71f61c0_U5n3Glr.jpg)
#
# The goal of this Etivity is to build and train your own Deep Convolutional Neural Network. This notebook contains standard keras/Tensorflow code to perform data processing, training set up and testing metrics, as outlined in the steps below. This will allow you to focus on developing the architecture & code for your network.
#
# 1. Load Dataset - We will import the CIFAR-10 Dataset using the Tensorflow Data Set API.
# 2. Prepare Data - We will slightly modify the dataset before it is sent to the model for training.
# 3. Model Coding - We will write code to build the model using the Tensorflow keras API.
#   * **You will code your neural network model in this section**
# 4. Compile Model - We will compile the model and verify that it has been correctly constructed.
# 5. Train Model - We will train the model using the imported dataset.
# 6. Test Model - We test the model on the training data and obtain a classification report and confusion matrix.
#
# The principal resource for understanding the basics of how to code & train Deep Convolutional Neural Network architectures in Tensorflow/keras are the Tensorflow tutorials. Tutorials on [image classification](https://www.tensorflow.org/tutorials/images/classification) and [data augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation) are useful for this Etivity.

# %% [markdown]
# ## (b) Notes on Architecture selection & development
#
# A key task in this Etivity is selecting an appropriate architecture. You can base your archicture on any of the types seen in the lecture notes or published literature. It is however recommended to ensure you can get a standard CNN type architecture to successfully train before attempting a more complex architecture or adding further enhancements to your network to improve performance.
#    Many published networks are designed to work with larger sized input images (e.g. 224 x 224). Often large (e.g. 7 x 7) convolution kernels and pooling layers are first applied to the input image, which agressively reduce the spatial dimensions of the network. As the CIFAR-10 dataset only has 32 x 32 images, it is recommended that just an intial 3 x 3 convolution is applied to the input image (as shown in the figure below), which will preserve the spatial dimensions of the input, before any other layers are added. It is expected that as you add more layers to the network the spatial dimensions will reduce and there will also be a corresponding increase the number of channels of the output feature map. The architecture will end with a [global average pooling layer](https://arxiv.org/pdf/1312.4400.pdf) and a fully-connected layer (called a *dense* layer in Keras/Tensorflow) with softmax activation which gives us our 10 class predictions. A skeleton code has been provided for any general architure using this structure in section 3.
# ![link text](https://github.com/tonyscan6003/CE6003/blob/master/images/Architecture_outline.jpg?raw=true)

# %% [markdown]
# #House Keeping

# %%
from __future__ import print_function

# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, RandomFlip, RandomTranslation
from tensorflow.keras.layers import GlobalAveragePooling2D, AveragePooling2D, Input, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10

import numpy as np

# %% [markdown]
# To ensure this assignment runs as fast as possible, from the menu above select **Edit > Notebook settings** or **Runtime > Change runtime type** and select GPU as the Hardware accelerator option.
#
# Let's test that we are running using the GPU.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# #1. Load Dataset
#
# In this assignment, we will be using the [CIFAR-10 dataset](http://www.cs.toronto.edu/~kriz/cifar.htmlhttps://). CIFAR-10 is often used as a "Hello World" dataset that is often used to ensure a network architecture is working before moving on to training with more complex datasets.
#
# The CIFAR-10 dataset consists of 60,000 32x32 color images in 10 classes (airplane, automobile, **bird**, cat, deer, dog, frog, horse, ship, truck), with 6,000 images per class. There are 50,000 training images and 10,000 test images.
#
# We will use the [Tensorflow dataset](https://www.tensorflow.org/datasets/catalog/cifar10) API to download the CIFAR10 dataset.

# %%
batch_size = 32 # Default Batch size (can be adjusted)
H_trg =32       # Image Height (fixed)
W_trg =32       # image Width (fixed)

# Labels corresponding to categories
label_str = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# We initally load the raw training/validation/test dataset
import tensorflow_datasets as tfds
ds,info= tfds.load("cifar10",with_info=True)

raw_train = tfds.load('cifar10', split='train[0%:90%]')
raw_val = tfds.load('cifar10', split='train[91%:100%]')
raw_test = tfds.load('cifar10', split='test')
# Out:
# Downloading and preparing dataset cifar10/3.0.2 (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incompleteFK7Q1Y/cifar10-train.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incompleteFK7Q1Y/cifar10-test.tfrecord
#   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# # 2. Prepare Data
#
# After importing raw datasets using tfds load, we create an input pipeline that processes & batches this data before it is supplied to the model for training using the virtual machine GPU.

# %%
def data_pipe(image,label):
  image = tf.image.convert_image_dtype(image, tf.float32) # Cast and normalize the image to [0,1]
  image = image-0.5
  label = tf.cast(label, tf.float32)
  return image,label

# %%
def gen_tr_datasets(src_dataset):    
    # Define Datasets 
    #src_dataset = src_dataset.shuffle(num_train_examples) 
    tr_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    tr_dataset = tr_dataset.map(data_pipe)
    tr_dataset = tr_dataset.batch(batch_size) 
    return tr_dataset

def gen_val_datasets(src_dataset): 
    # Define Datasets 
    test_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    test_dataset = test_dataset.map(data_pipe)
    test_dataset = test_dataset.batch(batch_size) 
    return test_dataset
# Generate the datasets
train_dataset = gen_tr_datasets(raw_train)
val_dataset = gen_val_datasets(raw_val)
test_dataset = gen_val_datasets(raw_test)

# %% [markdown]
# Plot some examples of the training dataset.

# %%
# plot training examples
i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image, label in train_dataset.take(n_plots):  # Only take a single example
  axarr[i].imshow(image[0,:,:,:]+0.5)
  axarr[i].axis('off')
  axarr[i].title.set_text(label_str[int(label[0])])
  i = i+1

# %% [markdown]
# # 3. Model Coding
#
# In this section You may develop your own model architecture to perform image recognition with the CIFAR-10 Dataset.
#
# There are some recommendations and helper code in this section that you may choose use, or you can also use your own approach to creating your architecture.
#
# Please Leave a note at the end of the notebook explaining your approach/results for the e-moderator.

# %% [markdown]
#
# ## Note 1: Keras Function/Sequential API
#
# Within Keras there are two API's for coding network models: Sequential and functional. You may have already used the [seqential model](https://https://www.tensorflow.org/guide/keras/sequential_model) to code basic artifical neural networks. The [functional model](https://www.tensorflow.org/guide/keras/functional) is more general and enables us to include feedforward paths which are required to code more advanced networks such as ResNet or DenseNet. The functional API has been used to code the helper functions repeating unit/top level skeleton detailed below.
#
# ## Note 2: Repeating Unit
#
# In many Deep architectures there will often be a repeating unit(s) that is composed of a sequence of layers, for example Conv,ReLU & Batch Normalisation. Specific layers can be turned on or off as required. This also allows experimentation of the entire architecture with/without specific layers (e.g. Batch Normalisation)  You may wish to create other combinations of layers or additional repeating units depending on your architecture.
#
# In the code cell below we can see an example of a `repeat_unit` function where the number of kernel filters and kernel size is specified. Batch Normalisation and activation layers can be turned on/off as required.
#
#  * Convolutional Layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
#  * Batch Normalization layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization)
#  * Activation layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Activation)

# %%
# Example of a Basic Repeating unit

def repeat_unit(inputs, num_channels=16, kernel_size=3,
                 strides=1, activation='relu', batch_normalization=False, avg_pooling=False):
    """
    inputs: Input to repeat unit.
    num_channels: number of channels in convolution layer of repeat unit, nominally = 16
    kernel_size: number of kernels to use in convolution, nominally = 3
    strides: number of strides for kernel, nominally = 1
    activation: type of activation applied to output of convolution, nominally ReLU. 
    x = output of repeat_unit
    """
    conv = Conv2D(num_channels, kernel_size=kernel_size, strides=strides, padding='same',
                  kernel_initializer='he_normal')
    x = conv(inputs)
    
    if activation is not None:
        x = Activation(activation)(x)

    if batch_normalization:
        x = BatchNormalization()(x)

    if avg_pooling:
        x = AveragePooling2D(pool_size=(2,2))(x)

    return x

# %%
def resnet_block(inputs, num_channels=16, kernel_size=3):

  x_shortcut = inputs # Store the initial value of X in a variable
  ## P3 repeat units 
  x = repeat_unit(inputs, num_channels=num_channels, kernel_size=kernel_size, strides = 1, activation='relu', batch_normalization=True)
  x = repeat_unit(x, num_channels=num_channels, kernel_size=kernel_size, strides = 1, activation='relu', batch_normalization=True)
  x = repeat_unit(x, num_channels=num_channels, kernel_size=kernel_size, strides = 1, activation=None, batch_normalization=True)

  x = keras.layers.Add()([x, x_shortcut]) # SKIP Connection

  x = Activation('relu')(x)
  return x

# %% [markdown]
# ## Note 3: Top Level
#
# In the code cell below, an incomplete skeleton function is provided for your top level.
# * This uses the Keras functional API
# * A single repeating unit which does not reduce the spatial dimensions of the input is placed at the top of the stack. You can change the number of channels/kernel size to suit your own architecture.
# * You can add your own layers/repeating units etc to build your own architecture with the function.
# * At the end of the stack we add a [global average pooling layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling2D) and fully connected [(Dense)](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) layer with softmax activation. (Alternatively to the Global Average pooling Dense layers can be used, this approach uses more parameter (memory) and is commonly seen in earlier Deeep Learning architectures such as AlexNet)

# %%
def network_top(input_shape,num_classes=10):
    """
    input Shape: (Define H,W, no. channels) of network input
                 used in Input definition below
    num_classes: Default = 10, sets output classes of network,
                 set to same no. of classes as CIFAR 10 Dataset 
    model:       keras Model returned by this function.                          
    """
       
    # Define input of model
    inputs = Input(shape=input_shape)

    # Add First repeating Unit
    x = repeat_unit(inputs=inputs, num_channels=16, batch_normalization=True)
  
    x = repeat_unit(x, num_channels=16, batch_normalization=True)
    for i in range(0,3):
      x = resnet_block(x, num_channels=16)

    x = repeat_unit(x, num_channels=32, batch_normalization=True,  avg_pooling=True)
    for i in range(0,3):
      x = resnet_block(x, num_channels=32)

    x = repeat_unit(x, num_channels=64, batch_normalization=True,  avg_pooling=True)
    for i in range(0,4):
      x = resnet_block(x, num_channels=64)


    # Add final stages. (Ensure that you call the output of the very last layer outputs)
    x = GlobalAveragePooling2D()(x)

    # Output Layer
    outputs = Dense(num_classes, activation='softmax', kernel_initializer='he_normal')(x)

    # Model definition
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # 4. Compile the Model
# Now that we have defined our functions to create the model, we'll instantiate the model and compile it.  Note that the compiling step in Keras, also configures the model for training. We define  loss function, the optimizer and metrics.
#
# Note the use here of [Sparse Categorical Crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy). This loss function allows us to input integer values for true classes. With the regular categorical cross entropy loss function the supplied labels must be frist converted to a one-hot representation,  but this special loss function allows us to avoid manually converting to the one-hot representation.

# %%
input_shape = (32,32,3)
model = network_top(input_shape=input_shape)
model.compile(loss='SparseCategoricalCrossentropy', optimizer=Adam(), metrics=['accuracy'])
model.summary()

# Uncomment the following line to plot the model visually - warning this may be quite large!
# keras.utils.plot_model(model, dpi=48)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   448         ['input_1[0][0]']
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['activation[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   2320        ['batch_normalization[0][0]']
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['conv2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['activation_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   2320        ['batch_normalization_1[0][0]']
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['conv2d_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['activation_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 16)   2320        ['batch_normalization_2[0][0]']
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['conv2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 16)  64          ['activation_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 16)   2320        ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 16)   0           ['batch_normalization_4[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['add[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['conv2d_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['activation_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 16)   2320        ['batch_normalization_5[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 16)   0           ['conv2d_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 16)  64          ['activation_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 16)   2320        ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_7[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['conv2d_8[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['activation_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 16)   2320        ['batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (None, 32, 32, 16)   0           ['conv2d_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 16)  64          ['activation_9[0][0]']
#  rmalization)
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 32, 32, 16)   0           ['batch_normalization_10[0][0]',
#                                                                   'activation_7[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 32)   4640        ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 32)   0           ['conv2d_11[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 32)  128         ['activation_11[0][0]']
#  ormalization)
#
#  average_pooling2d (AveragePool  (None, 16, 16, 32)  0           ['batch_normalization_11[0][0]']
#  ing2D)
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 32)   9248        ['average_pooling2d[0][0]']
#
#  activation_12 (Activation)     (None, 16, 16, 32)   0           ['conv2d_12[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 32)  128         ['activation_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 32)   9248        ['batch_normalization_12[0][0]']
#
#  activation_13 (Activation)     (None, 16, 16, 32)   0           ['conv2d_13[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 32)  128         ['activation_13[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 32)   9248        ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 32)  128         ['conv2d_14[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 16, 16, 32)   0           ['batch_normalization_14[0][0]',
#                                                                   'average_pooling2d[0][0]']
#
#  activation_14 (Activation)     (None, 16, 16, 32)   0           ['add_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 16, 16, 32)   0           ['conv2d_15[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 32)  128         ['activation_15[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 32)   9248        ['batch_normalization_15[0][0]']
#
#  activation_16 (Activation)     (None, 16, 16, 32)   0           ['conv2d_16[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 32)  128         ['activation_16[0][0]']
#  ormalization)
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 32)   9248        ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 32)  128         ['conv2d_17[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 16, 16, 32)   0           ['batch_normalization_17[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_17 (Activation)     (None, 16, 16, 32)   0           ['add_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_17[0][0]']
#
#  activation_18 (Activation)     (None, 16, 16, 32)   0           ['conv2d_18[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 32)  128         ['activation_18[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 32)   9248        ['batch_normalization_18[0][0]']
#
#  activation_19 (Activation)     (None, 16, 16, 32)   0           ['conv2d_19[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 32)  128         ['activation_19[0][0]']
#  ormalization)
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 32)   9248        ['batch_normalization_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 32)  128         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 16, 16, 32)   0           ['batch_normalization_20[0][0]',
#                                                                   'activation_17[0][0]']
#
#  activation_20 (Activation)     (None, 16, 16, 32)   0           ['add_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 64)   18496       ['activation_20[0][0]']
#
#  activation_21 (Activation)     (None, 16, 16, 64)   0           ['conv2d_21[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 64)  256         ['activation_21[0][0]']
#  ormalization)
#
#  average_pooling2d_1 (AveragePo  (None, 8, 8, 64)    0           ['batch_normalization_21[0][0]']
#  oling2D)
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 64)     36928       ['average_pooling2d_1[0][0]']
#
#  activation_22 (Activation)     (None, 8, 8, 64)     0           ['conv2d_22[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 64)    256         ['activation_22[0][0]']
#  ormalization)
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 64)     36928       ['batch_normalization_22[0][0]']
#
#  activation_23 (Activation)     (None, 8, 8, 64)     0           ['conv2d_23[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 64)    256         ['activation_23[0][0]']
#  ormalization)
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 64)     36928       ['batch_normalization_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 64)    256         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 8, 8, 64)     0           ['batch_normalization_24[0][0]',
#                                                                   'average_pooling2d_1[0][0]']
#
#  activation_24 (Activation)     (None, 8, 8, 64)     0           ['add_6[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_24[0][0]']
#
#  activation_25 (Activation)     (None, 8, 8, 64)     0           ['conv2d_25[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 64)    256         ['activation_25[0][0]']
#  ormalization)
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 64)     36928       ['batch_normalization_25[0][0]']
#
#  activation_26 (Activation)     (None, 8, 8, 64)     0           ['conv2d_26[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 64)    256         ['activation_26[0][0]']
#  ormalization)
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 64)     36928       ['batch_normalization_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 64)    256         ['conv2d_27[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 8, 8, 64)     0           ['batch_normalization_27[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 8, 8, 64)     0           ['add_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_27[0][0]']
#
#  activation_28 (Activation)     (None, 8, 8, 64)     0           ['conv2d_28[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 8, 8, 64)    256         ['activation_28[0][0]']
#  ormalization)
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 64)     36928       ['batch_normalization_28[0][0]']
#
#  activation_29 (Activation)     (None, 8, 8, 64)     0           ['conv2d_29[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 64)    256         ['activation_29[0][0]']
#  ormalization)
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 64)     36928       ['batch_normalization_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 64)    256         ['conv2d_30[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 8, 8, 64)     0           ['batch_normalization_30[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 8, 8, 64)     0           ['add_8[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 8, 8, 64)     0           ['conv2d_31[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 64)    256         ['activation_31[0][0]']
#  ormalization)
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 64)     36928       ['batch_normalization_31[0][0]']
#
#  activation_32 (Activation)     (None, 8, 8, 64)     0           ['conv2d_32[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 64)    256         ['activation_32[0][0]']
#  ormalization)
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 64)     36928       ['batch_normalization_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 64)    256         ['conv2d_33[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 8, 8, 64)     0           ['batch_normalization_33[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 8, 8, 64)     0           ['add_9[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['activation_33[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           650         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 579,114
# Trainable params: 576,458
# Non-trainable params: 2,656
# __________________________________________________________________________________________________

# %% [markdown]
# # 5. Model Training
#
# We will now train the complied model on the cifar10 dataset using the tensorflow keras `model.fit` method.

# %%
epochs =55
history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=val_dataset)
# Out:
# Epoch 1/55
# 1407/1407 [==============================] - 101s 62ms/step - loss: 1.4545 - accuracy: 0.4721 - val_loss: 1.2296 - val_accuracy: 0.5553
# Epoch 2/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.9887 - accuracy: 0.6523 - val_loss: 1.0105 - val_accuracy: 0.6520
# Epoch 3/55
# 1407/1407 [==============================] - 78s 55ms/step - loss: 0.7582 - accuracy: 0.7379 - val_loss: 0.8380 - val_accuracy: 0.7131
# Epoch 4/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.6137 - accuracy: 0.7892 - val_loss: 0.7831 - val_accuracy: 0.7364
# Epoch 5/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.5103 - accuracy: 0.8226 - val_loss: 0.6751 - val_accuracy: 0.7778
# Epoch 6/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.4320 - accuracy: 0.8520 - val_loss: 0.7232 - val_accuracy: 0.7644
# Epoch 7/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.3613 - accuracy: 0.8742 - val_loss: 0.7200 - val_accuracy: 0.7700
# Epoch 8/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.3088 - accuracy: 0.8913 - val_loss: 0.7074 - val_accuracy: 0.7944
# Epoch 9/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.2572 - accuracy: 0.9089 - val_loss: 0.8753 - val_accuracy: 0.7671
# Epoch 10/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.2202 - accuracy: 0.9207 - val_loss: 0.7885 - val_accuracy: 0.7856
# Epoch 11/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.1887 - accuracy: 0.9318 - val_loss: 0.8166 - val_accuracy: 0.7920
# Epoch 12/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.1658 - accuracy: 0.9417 - val_loss: 0.7676 - val_accuracy: 0.8071
# Epoch 13/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.1492 - accuracy: 0.9464 - val_loss: 0.8083 - val_accuracy: 0.8011
# Epoch 14/55
# 1407/1407 [==============================] - 78s 55ms/step - loss: 0.1331 - accuracy: 0.9531 - val_loss: 0.9311 - val_accuracy: 0.7893
# Epoch 15/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.1173 - accuracy: 0.9586 - val_loss: 0.8381 - val_accuracy: 0.8027
# Epoch 16/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.1079 - accuracy: 0.9617 - val_loss: 0.7866 - val_accuracy: 0.8107
# Epoch 17/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0999 - accuracy: 0.9644 - val_loss: 0.7976 - val_accuracy: 0.8160
# Epoch 18/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0885 - accuracy: 0.9683 - val_loss: 0.9017 - val_accuracy: 0.7980
# Epoch 19/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.0859 - accuracy: 0.9690 - val_loss: 0.9537 - val_accuracy: 0.7998
# Epoch 20/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.0870 - accuracy: 0.9690 - val_loss: 0.7765 - val_accuracy: 0.8240
# Epoch 21/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.0697 - accuracy: 0.9751 - val_loss: 0.9664 - val_accuracy: 0.7996
# Epoch 22/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.0735 - accuracy: 0.9742 - val_loss: 0.8728 - val_accuracy: 0.8153
# Epoch 23/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.0657 - accuracy: 0.9760 - val_loss: 0.8093 - val_accuracy: 0.8320
# Epoch 24/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.0592 - accuracy: 0.9793 - val_loss: 0.8376 - val_accuracy: 0.8236
# Epoch 25/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.0612 - accuracy: 0.9786 - val_loss: 0.9228 - val_accuracy: 0.8176
# Epoch 26/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0647 - accuracy: 0.9771 - val_loss: 0.9223 - val_accuracy: 0.8222
# Epoch 27/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0522 - accuracy: 0.9819 - val_loss: 0.9146 - val_accuracy: 0.8260
# Epoch 28/55
# 1407/1407 [==============================] - 78s 56ms/step - loss: 0.0537 - accuracy: 0.9814 - val_loss: 0.9718 - val_accuracy: 0.8089
# Epoch 29/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0462 - accuracy: 0.9840 - val_loss: 0.8618 - val_accuracy: 0.8287
# Epoch 30/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0511 - accuracy: 0.9818 - val_loss: 0.9388 - val_accuracy: 0.8247
# Epoch 31/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0446 - accuracy: 0.9848 - val_loss: 0.9297 - val_accuracy: 0.8162
# Epoch 32/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0463 - accuracy: 0.9841 - val_loss: 0.9411 - val_accuracy: 0.8307
# Epoch 33/55
# 1407/1407 [==============================] - 80s 56ms/step - loss: 0.0442 - accuracy: 0.9850 - val_loss: 0.9773 - val_accuracy: 0.8187
# Epoch 34/55
# 1407/1407 [==============================] - 80s 57ms/step - loss: 0.0402 - accuracy: 0.9856 - val_loss: 0.9602 - val_accuracy: 0.8291
# Epoch 35/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0400 - accuracy: 0.9865 - val_loss: 0.9320 - val_accuracy: 0.8240
# Epoch 36/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0436 - accuracy: 0.9851 - val_loss: 0.8971 - val_accuracy: 0.8389
# Epoch 37/55
# 1407/1407 [==============================] - 80s 57ms/step - loss: 0.0337 - accuracy: 0.9876 - val_loss: 0.9547 - val_accuracy: 0.8327
# Epoch 38/55
# 1407/1407 [==============================] - 80s 57ms/step - loss: 0.0367 - accuracy: 0.9869 - val_loss: 0.9639 - val_accuracy: 0.8273
# Epoch 39/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0351 - accuracy: 0.9880 - val_loss: 0.9814 - val_accuracy: 0.8296
# Epoch 40/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0351 - accuracy: 0.9876 - val_loss: 0.9664 - val_accuracy: 0.8333
# Epoch 41/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0302 - accuracy: 0.9895 - val_loss: 0.9687 - val_accuracy: 0.8278
# Epoch 42/55
# 1407/1407 [==============================] - 80s 57ms/step - loss: 0.0321 - accuracy: 0.9889 - val_loss: 0.9468 - val_accuracy: 0.8251
# Epoch 43/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0319 - accuracy: 0.9890 - val_loss: 0.9610 - val_accuracy: 0.8293
# Epoch 44/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0304 - accuracy: 0.9892 - val_loss: 0.9608 - val_accuracy: 0.8349
# Epoch 45/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0291 - accuracy: 0.9900 - val_loss: 0.9433 - val_accuracy: 0.8367
# Epoch 46/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0311 - accuracy: 0.9892 - val_loss: 1.0130 - val_accuracy: 0.8309
# Epoch 47/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0288 - accuracy: 0.9900 - val_loss: 0.9884 - val_accuracy: 0.8333
# Epoch 48/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0254 - accuracy: 0.9915 - val_loss: 0.9957 - val_accuracy: 0.8393
# Epoch 49/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0303 - accuracy: 0.9899 - val_loss: 1.0189 - val_accuracy: 0.8347
# Epoch 50/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0274 - accuracy: 0.9909 - val_loss: 0.9915 - val_accuracy: 0.8342
# Epoch 51/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 0.9931 - val_accuracy: 0.8331
# Epoch 52/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0277 - accuracy: 0.9905 - val_loss: 0.9760 - val_accuracy: 0.8400
# Epoch 53/55
# 1407/1407 [==============================] - 80s 57ms/step - loss: 0.0216 - accuracy: 0.9927 - val_loss: 1.0379 - val_accuracy: 0.8340
# Epoch 54/55
# 1407/1407 [==============================] - 80s 57ms/step - loss: 0.0284 - accuracy: 0.9898 - val_loss: 1.0326 - val_accuracy: 0.8316
# Epoch 55/55
# 1407/1407 [==============================] - 79s 56ms/step - loss: 0.0233 - accuracy: 0.9920 - val_loss: 1.0423 - val_accuracy: 0.8304

# %% [markdown]
# We will plot the loss and accuracy for the training and validation data sets.

# %%
print(history.history.keys())
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # 6. Model Testing
# We will iterate through the test data and analyse the results using tools from sklearn. We create a classification report, a confusion matrix and also plot a few examples from the test set.

# %% [markdown]
# Iterate through n_test batches and store the predicted and ground truth labels in numpy arrays.

# %%
n_test = 100 # number of batches to use
store_predictions = []
store_labels = []
for image_batch,label_batch in test_dataset.take(n_test):
    predictions = model.predict_on_batch(image_batch) 
    predictions = tf.math.argmax(predictions,axis=1)
    store_predictions.append(predictions)
    store_labels.append(label_batch)
y_pred = np.squeeze(np.reshape(store_predictions,(1,n_test*batch_size)))
y_true = np.squeeze(np.reshape(store_labels,(1,n_test*batch_size)))

# %% [markdown]
# Create and plot a confusion matrix.

# %%
#https://scikit-learn.org/0.16/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_str))
    plt.xticks(tick_marks, label_str, rotation=45)
    plt.yticks(tick_marks, label_str)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm)

# %% [markdown]
# Generate & print the classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=label_str))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.85      0.85      0.85       337
#   automobile       0.89      0.95      0.92       338
#         bird       0.82      0.78      0.80       306
#          cat       0.65      0.68      0.66       323
#         deer       0.83      0.79      0.81       297
#          dog       0.72      0.81      0.76       325
#         frog       0.92      0.80      0.85       307
#        horse       0.89      0.86      0.87       317
#         ship       0.95      0.92      0.93       326
#        truck       0.88      0.90      0.89       324
#
#     accuracy                           0.84      3200
#    macro avg       0.84      0.83      0.84      3200
# weighted avg       0.84      0.84      0.84      3200

# %% [markdown]
# Plot some test images and predicted labels.

# %%
#Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)
print(np.shape(predictions))
# Apply a sigmoid since our model returns logits
predictions = tf.math.argmax(predictions,axis=1)
print(np.shape(predictions))
print('Predictions:\n', predictions.numpy())


i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image in image_batch[0:n_plots,:,:,:]:  # Only take a single example
  axarr[i].imshow(image[:,:,:]+0.5)
  axarr[i].axis('off')
  
  color = ('black' if predictions[i] == int(label_batch[i]) else 'red') 
  axarr[i].set_title(label_str[int(predictions[i])],fontsize='small', color=color)
  i = i+1
# Out:
# (32, 10)
# (32,)
# Predictions:
#  [2 0 6 9 5 1 7 0 3 7 7 2 7 9 5 8 2 8 7 9 4 5 3 5 3 8 6 8 1 8 2 0]

# %% [markdown]
# # Please Leave a note here explaining your approach/results for the e-moderator.
