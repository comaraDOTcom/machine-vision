# %% [markdown]
# <a href="https://colab.research.google.com/github/comaraDOTcom/machine-vision/blob/main/deep-learning/Etivity_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Etivity 2
# Name: Conor O'Mara
# Student number: 20151845

# %% [markdown]
# # Etivity 2: Deep Convolutional Neural Network on CIFAR-10 Dataset
#
# In this assignment, we will gain some practical experience of coding a deep convolutional neural network in Tensorflow. The simplest way to code a network is to use the High level Keras API within Tensorflow 2.5.
#
# ## (a) Introduction
#
#  In this assignment to reduce training time and computation, we will train our network using the simple [CIFAR10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset.
# ![link text](https://paperswithcode.com/media/datasets/CIFAR-10-0000000431-b71f61c0_U5n3Glr.jpg)
#
# The goal of this Etivity is to build and train your own Deep Convolutional Neural Network. This notebook contains standard keras/Tensorflow code to perform data processing, training set up and testing metrics, as outlined in the steps below. This will allow you to focus on developing the architecture & code for your network.
#
# 1. Load Dataset - We will import the CIFAR-10 Dataset using the Tensorflow Data Set API.
# 2. Prepare Data - We will slightly modify the dataset before it is sent to the model for training.
# 3. Model Coding - We will write code to build the model using the Tensorflow keras API.
#   * **You will code your neural network model in this section**
# 4. Compile Model - We will compile the model and verify that it has been correctly constructed.
# 5. Train Model - We will train the model using the imported dataset.
# 6. Test Model - We test the model on the training data and obtain a classification report and confusion matrix.
#
# The principal resource for understanding the basics of how to code & train Deep Convolutional Neural Network architectures in Tensorflow/keras are the Tensorflow tutorials. Tutorials on [image classification](https://www.tensorflow.org/tutorials/images/classification) and [data augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation) are useful for this Etivity.

# %% [markdown]
# ## (b) Notes on Architecture selection & development
#
# A key task in this Etivity is selecting an appropriate architecture. You can base your archicture on any of the types seen in the lecture notes or published literature. It is however recommended to ensure you can get a standard CNN type architecture to successfully train before attempting a more complex architecture or adding further enhancements to your network to improve performance.
#    Many published networks are designed to work with larger sized input images (e.g. 224 x 224). Often large (e.g. 7 x 7) convolution kernels and pooling layers are first applied to the input image, which agressively reduce the spatial dimensions of the network. As the CIFAR-10 dataset only has 32 x 32 images, it is recommended that just an intial 3 x 3 convolution is applied to the input image (as shown in the figure below), which will preserve the spatial dimensions of the input, before any other layers are added. It is expected that as you add more layers to the network the spatial dimensions will reduce and there will also be a corresponding increase the number of channels of the output feature map. The architecture will end with a [global average pooling layer](https://arxiv.org/pdf/1312.4400.pdf) and a fully-connected layer (called a *dense* layer in Keras/Tensorflow) with softmax activation which gives us our 10 class predictions. A skeleton code has been provided for any general architure using this structure in section 3.
# ![link text](https://github.com/tonyscan6003/CE6003/blob/master/images/Architecture_outline.jpg?raw=true)

# %% [markdown]
# #House Keeping

# %%
from __future__ import print_function

# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, RandomFlip, RandomTranslation
from tensorflow.keras.layers import GlobalAveragePooling2D, AveragePooling2D, Input, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import cifar10

import numpy as np

# %% [markdown]
# To ensure this assignment runs as fast as possible, from the menu above select **Edit > Notebook settings** or **Runtime > Change runtime type** and select GPU as the Hardware accelerator option.
#
# Let's test that we are running using the GPU.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# #1. Load Dataset
#
# In this assignment, we will be using the [CIFAR-10 dataset](http://www.cs.toronto.edu/~kriz/cifar.htmlhttps://). CIFAR-10 is often used as a "Hello World" dataset that is often used to ensure a network architecture is working before moving on to training with more complex datasets.
#
# The CIFAR-10 dataset consists of 60,000 32x32 color images in 10 classes (airplane, automobile, **bird**, cat, deer, dog, frog, horse, ship, truck), with 6,000 images per class. There are 50,000 training images and 10,000 test images.
#
# We will use the [Tensorflow dataset](https://www.tensorflow.org/datasets/catalog/cifar10) API to download the CIFAR10 dataset.

# %%
batch_size = 32 # Default Batch size (can be adjusted)
H_trg =32       # Image Height (fixed)
W_trg =32       # image Width (fixed)

# Labels corresponding to categories
label_str = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# We initally load the raw training/validation/test dataset
import tensorflow_datasets as tfds
ds,info= tfds.load("cifar10",with_info=True)

raw_train = tfds.load('cifar10', split='train[0%:90%]')
raw_val = tfds.load('cifar10', split='train[91%:100%]')
raw_test = tfds.load('cifar10', split='test')
# Out:
# Downloading and preparing dataset cifar10/3.0.2 (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incompleteYX56JI/cifar10-train.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incompleteYX56JI/cifar10-test.tfrecord
#   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# # 2. Prepare Data
#
# After importing raw datasets using tfds load, we create an input pipeline that processes & batches this data before it is supplied to the model for training using the virtual machine GPU.

# %%
def data_pipe(image,label):
  image = tf.image.convert_image_dtype(image, tf.float32) # Cast and normalize the image to [0,1]
  image = image-0.5
  label = tf.cast(label, tf.float32)
  return image,label

# %%
def gen_tr_datasets(src_dataset):    
    # Define Datasets 
    #src_dataset = src_dataset.shuffle(num_train_examples) 
    tr_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    tr_dataset = tr_dataset.map(data_pipe)
    tr_dataset = tr_dataset.batch(batch_size) 
    return tr_dataset

def gen_val_datasets(src_dataset): 
    # Define Datasets 
    test_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    test_dataset = test_dataset.map(data_pipe)
    test_dataset = test_dataset.batch(batch_size) 
    return test_dataset
# Generate the datasets
train_dataset = gen_tr_datasets(raw_train)
val_dataset = gen_val_datasets(raw_val)
test_dataset = gen_val_datasets(raw_test)

# %% [markdown]
# Plot some examples of the training dataset.

# %%
# plot training examples
i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image, label in train_dataset.take(n_plots):  # Only take a single example
  axarr[i].imshow(image[0,:,:,:]+0.5)
  axarr[i].axis('off')
  axarr[i].title.set_text(label_str[int(label[0])])
  i = i+1

# %% [markdown]
# # 3. Model Coding
#
# In this section You may develop your own model architecture to perform image recognition with the CIFAR-10 Dataset.
#
# There are some recommendations and helper code in this section that you may choose use, or you can also use your own approach to creating your architecture.
#
# Please Leave a note at the end of the notebook explaining your approach/results for the e-moderator.

# %% [markdown]
#
# ## Note 1: Keras Function/Sequential API
#
# Within Keras there are two API's for coding network models: Sequential and functional. You may have already used the [seqential model](https://https://www.tensorflow.org/guide/keras/sequential_model) to code basic artifical neural networks. The [functional model](https://www.tensorflow.org/guide/keras/functional) is more general and enables us to include feedforward paths which are required to code more advanced networks such as ResNet or DenseNet. The functional API has been used to code the helper functions repeating unit/top level skeleton detailed below.
#
# ## Note 2: Repeating Unit
#
# In many Deep architectures there will often be a repeating unit(s) that is composed of a sequence of layers, for example Conv,ReLU & Batch Normalisation. Specific layers can be turned on or off as required. This also allows experimentation of the entire architecture with/without specific layers (e.g. Batch Normalisation)  You may wish to create other combinations of layers or additional repeating units depending on your architecture.
#
# In the code cell below we can see an example of a `repeat_unit` function where the number of kernel filters and kernel size is specified. Batch Normalisation and activation layers can be turned on/off as required.
#
#  * Convolutional Layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
#  * Batch Normalization layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization)
#  * Activation layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Activation)

# %%
# Example of a Basic Repeating unit

def repeat_unit(inputs, num_channels=16, kernel_size=3,
                 strides=1, activation='relu', batch_normalization=False, avg_pooling=False, dropout=None , kernel_regularizer=None):
    """
    inputs: Input to repeat unit.
    num_channels: number of channels in convolution layer of repeat unit, nominally = 16
    kernel_size: number of kernels to use in convolution, nominally = 3
    strides: number of strides for kernel, nominally = 1
    activation: type of activation applied to output of convolution, nominally ReLU. 
    x = output of repeat_unit
    """
    conv = Conv2D(num_channels, kernel_size=kernel_size, strides=strides, padding='same',
                  kernel_initializer='he_normal', kernel_regularizer=kernel_regularizer)
    x = conv(inputs)
    
    if activation is not None:
        x = Activation(activation)(x)

    if batch_normalization:
        x = BatchNormalization()(x)

    if avg_pooling:
        x = AveragePooling2D(pool_size=(2,2))(x)

    if dropout is not None:
        x = Dropout(dropout)(x) 

    return x

# %%
def resnet_block(inputs, num_channels=16, kernel_size=3):

  x_shortcut = inputs # Store the initial value of X in a variable
  ## P3 repeat units 
  x = repeat_unit(inputs, num_channels=num_channels, kernel_size=kernel_size, strides = 1, activation='relu', batch_normalization=True, kernel_regularizer='l1')
  x = repeat_unit(x, num_channels=num_channels, kernel_size=kernel_size, strides = 1, activation='relu', batch_normalization=True)
  x = repeat_unit(x, num_channels=num_channels, kernel_size=kernel_size, strides = 1, activation=None, batch_normalization=True)
  
  x = keras.layers.Add()([x, x_shortcut]) # SKIP Connection

  x = Activation('relu')(x)
  return x

# %% [markdown]
# ## Note 3: Top Level
#
# In the code cell below, an incomplete skeleton function is provided for your top level.
# * This uses the Keras functional API
# * A single repeating unit which does not reduce the spatial dimensions of the input is placed at the top of the stack. You can change the number of channels/kernel size to suit your own architecture.
# * You can add your own layers/repeating units etc to build your own architecture with the function.
# * At the end of the stack we add a [global average pooling layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling2D) and fully connected [(Dense)](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) layer with softmax activation. (Alternatively to the Global Average pooling Dense layers can be used, this approach uses more parameter (memory) and is commonly seen in earlier Deeep Learning architectures such as AlexNet)

# %%
def network_top(input_shape,num_classes=10):
    """
    input Shape: (Define H,W, no. channels) of network input
                 used in Input definition below
    num_classes: Default = 10, sets output classes of network,
                 set to same no. of classes as CIFAR 10 Dataset 
    model:       keras Model returned by this function.                          
    """
       
    # Define input of model
    inputs = Input(shape=input_shape)

    # Add First repeating Unit
    x = repeat_unit(inputs=inputs, num_channels=16, batch_normalization=True)
  
    x = repeat_unit(x, num_channels=16, batch_normalization=True)
    for i in range(0,3):
      x = resnet_block(x, num_channels=16)
      
    x = MaxPooling2D(2, 2)(x)
    x = repeat_unit(x, num_channels=32, batch_normalization=True,  avg_pooling=True, kernel_regularizer='l1')
    for i in range(0,3):
      x = resnet_block(x, num_channels=32)

    x = repeat_unit(x, num_channels=64, batch_normalization=True,  avg_pooling=True, kernel_regularizer='l1', dropout=0.25)
    for i in range(0,3):
      x = resnet_block(x, num_channels=64)

    x = MaxPooling2D(2, 2)(x)
    x = repeat_unit(x, num_channels=128, batch_normalization=True,  avg_pooling=True, kernel_regularizer='l1', dropout=0.1)
    for i in range(0,3):
      x = resnet_block(x, num_channels=128)


    # Add final stages. (Ensure that you call the output of the very last layer outputs)
    x = GlobalAveragePooling2D()(x)

    x = Flatten()(x)
    x = Dense(256, activation='relu', kernel_initializer='he_uniform')(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.25)(x)

    # Output Layer
    outputs = Dense(num_classes, activation='softmax', kernel_initializer='he_normal')(x)

    # Model definition
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # 4. Compile the Model
# Now that we have defined our functions to create the model, we'll instantiate the model and compile it.  Note that the compiling step in Keras, also configures the model for training. We define  loss function, the optimizer and metrics.
#
# Note the use here of [Sparse Categorical Crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy). This loss function allows us to input integer values for true classes. With the regular categorical cross entropy loss function the supplied labels must be frist converted to a one-hot representation,  but this special loss function allows us to avoid manually converting to the one-hot representation.

# %%
input_shape = (32,32,3)
model = network_top(input_shape=input_shape)
model.compile(loss='SparseCategoricalCrossentropy', optimizer=Adam(), metrics=['accuracy'])
model.summary()

# Plot the model visually
keras.utils.plot_model(model, dpi=60)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_143 (Conv2D)            (None, 32, 32, 16)   448         ['input_5[0][0]']
#
#  activation_143 (Activation)    (None, 32, 32, 16)   0           ['conv2d_143[0][0]']
#
#  batch_normalization_143 (Batch  (None, 32, 32, 16)  64          ['activation_143[0][0]']
#  Normalization)
#
#  conv2d_144 (Conv2D)            (None, 32, 32, 16)   2320        ['batch_normalization_143[0][0]']
#
#  activation_144 (Activation)    (None, 32, 32, 16)   0           ['conv2d_144[0][0]']
#
#  batch_normalization_144 (Batch  (None, 32, 32, 16)  64          ['activation_144[0][0]']
#  Normalization)
#
#  conv2d_145 (Conv2D)            (None, 32, 32, 16)   2320        ['batch_normalization_144[0][0]']
#
#  activation_145 (Activation)    (None, 32, 32, 16)   0           ['conv2d_145[0][0]']
#
#  batch_normalization_145 (Batch  (None, 32, 32, 16)  64          ['activation_145[0][0]']
#  Normalization)
#
#  conv2d_146 (Conv2D)            (None, 32, 32, 16)   2320        ['batch_normalization_145[0][0]']
#
#  activation_146 (Activation)    (None, 32, 32, 16)   0           ['conv2d_146[0][0]']
#
#  batch_normalization_146 (Batch  (None, 32, 32, 16)  64          ['activation_146[0][0]']
#  Normalization)
#
#  conv2d_147 (Conv2D)            (None, 32, 32, 16)   2320        ['batch_normalization_146[0][0]']
#
#  batch_normalization_147 (Batch  (None, 32, 32, 16)  64          ['conv2d_147[0][0]']
#  Normalization)
#
#  add_42 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_147[0][0]',
#                                                                   'batch_normalization_144[0][0]']
#
#  activation_147 (Activation)    (None, 32, 32, 16)   0           ['add_42[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_147[0][0]']
#
#  activation_148 (Activation)    (None, 32, 32, 16)   0           ['conv2d_148[0][0]']
#
#  batch_normalization_148 (Batch  (None, 32, 32, 16)  64          ['activation_148[0][0]']
#  Normalization)
#
#  conv2d_149 (Conv2D)            (None, 32, 32, 16)   2320        ['batch_normalization_148[0][0]']
#
#  activation_149 (Activation)    (None, 32, 32, 16)   0           ['conv2d_149[0][0]']
#
#  batch_normalization_149 (Batch  (None, 32, 32, 16)  64          ['activation_149[0][0]']
#  Normalization)
#
#  conv2d_150 (Conv2D)            (None, 32, 32, 16)   2320        ['batch_normalization_149[0][0]']
#
#  batch_normalization_150 (Batch  (None, 32, 32, 16)  64          ['conv2d_150[0][0]']
#  Normalization)
#
#  add_43 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_150[0][0]',
#                                                                   'activation_147[0][0]']
#
#  activation_150 (Activation)    (None, 32, 32, 16)   0           ['add_43[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_150[0][0]']
#
#  activation_151 (Activation)    (None, 32, 32, 16)   0           ['conv2d_151[0][0]']
#
#  batch_normalization_151 (Batch  (None, 32, 32, 16)  64          ['activation_151[0][0]']
#  Normalization)
#
#  conv2d_152 (Conv2D)            (None, 32, 32, 16)   2320        ['batch_normalization_151[0][0]']
#
#  activation_152 (Activation)    (None, 32, 32, 16)   0           ['conv2d_152[0][0]']
#
#  batch_normalization_152 (Batch  (None, 32, 32, 16)  64          ['activation_152[0][0]']
#  Normalization)
#
#  conv2d_153 (Conv2D)            (None, 32, 32, 16)   2320        ['batch_normalization_152[0][0]']
#
#  batch_normalization_153 (Batch  (None, 32, 32, 16)  64          ['conv2d_153[0][0]']
#  Normalization)
#
#  add_44 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_153[0][0]',
#                                                                   'activation_150[0][0]']
#
#  activation_153 (Activation)    (None, 32, 32, 16)   0           ['add_44[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 32, 32, 32)   4640        ['activation_153[0][0]']
#
#  activation_154 (Activation)    (None, 32, 32, 32)   0           ['conv2d_154[0][0]']
#
#  batch_normalization_154 (Batch  (None, 32, 32, 32)  128         ['activation_154[0][0]']
#  Normalization)
#
#  average_pooling2d_9 (AveragePo  (None, 16, 16, 32)  0           ['batch_normalization_154[0][0]']
#  oling2D)
#
#  conv2d_155 (Conv2D)            (None, 16, 16, 32)   9248        ['average_pooling2d_9[0][0]']
#
#  activation_155 (Activation)    (None, 16, 16, 32)   0           ['conv2d_155[0][0]']
#
#  batch_normalization_155 (Batch  (None, 16, 16, 32)  128         ['activation_155[0][0]']
#  Normalization)
#
#  conv2d_156 (Conv2D)            (None, 16, 16, 32)   9248        ['batch_normalization_155[0][0]']
#
#  activation_156 (Activation)    (None, 16, 16, 32)   0           ['conv2d_156[0][0]']
#
#  batch_normalization_156 (Batch  (None, 16, 16, 32)  128         ['activation_156[0][0]']
#  Normalization)
#
#  conv2d_157 (Conv2D)            (None, 16, 16, 32)   9248        ['batch_normalization_156[0][0]']
#
#  batch_normalization_157 (Batch  (None, 16, 16, 32)  128         ['conv2d_157[0][0]']
#  Normalization)
#
#  add_45 (Add)                   (None, 16, 16, 32)   0           ['batch_normalization_157[0][0]',
#                                                                   'average_pooling2d_9[0][0]']
#
#  activation_157 (Activation)    (None, 16, 16, 32)   0           ['add_45[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_157[0][0]']
#
#  activation_158 (Activation)    (None, 16, 16, 32)   0           ['conv2d_158[0][0]']
#
#  batch_normalization_158 (Batch  (None, 16, 16, 32)  128         ['activation_158[0][0]']
#  Normalization)
#
#  conv2d_159 (Conv2D)            (None, 16, 16, 32)   9248        ['batch_normalization_158[0][0]']
#
#  activation_159 (Activation)    (None, 16, 16, 32)   0           ['conv2d_159[0][0]']
#
#  batch_normalization_159 (Batch  (None, 16, 16, 32)  128         ['activation_159[0][0]']
#  Normalization)
#
#  conv2d_160 (Conv2D)            (None, 16, 16, 32)   9248        ['batch_normalization_159[0][0]']
#
#  batch_normalization_160 (Batch  (None, 16, 16, 32)  128         ['conv2d_160[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 16, 16, 32)   0           ['batch_normalization_160[0][0]',
#                                                                   'activation_157[0][0]']
#
#  activation_160 (Activation)    (None, 16, 16, 32)   0           ['add_46[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_160[0][0]']
#
#  activation_161 (Activation)    (None, 16, 16, 32)   0           ['conv2d_161[0][0]']
#
#  batch_normalization_161 (Batch  (None, 16, 16, 32)  128         ['activation_161[0][0]']
#  Normalization)
#
#  conv2d_162 (Conv2D)            (None, 16, 16, 32)   9248        ['batch_normalization_161[0][0]']
#
#  activation_162 (Activation)    (None, 16, 16, 32)   0           ['conv2d_162[0][0]']
#
#  batch_normalization_162 (Batch  (None, 16, 16, 32)  128         ['activation_162[0][0]']
#  Normalization)
#
#  conv2d_163 (Conv2D)            (None, 16, 16, 32)   9248        ['batch_normalization_162[0][0]']
#
#  batch_normalization_163 (Batch  (None, 16, 16, 32)  128         ['conv2d_163[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 16, 16, 32)   0           ['batch_normalization_163[0][0]',
#                                                                   'activation_160[0][0]']
#
#  activation_163 (Activation)    (None, 16, 16, 32)   0           ['add_47[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 16, 16, 64)   18496       ['activation_163[0][0]']
#
#  activation_164 (Activation)    (None, 16, 16, 64)   0           ['conv2d_164[0][0]']
#
#  batch_normalization_164 (Batch  (None, 16, 16, 64)  256         ['activation_164[0][0]']
#  Normalization)
#
#  average_pooling2d_10 (AverageP  (None, 8, 8, 64)    0           ['batch_normalization_164[0][0]']
#  ooling2D)
#
#  dropout_8 (Dropout)            (None, 8, 8, 64)     0           ['average_pooling2d_10[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 8, 8, 64)     36928       ['dropout_8[0][0]']
#
#  activation_165 (Activation)    (None, 8, 8, 64)     0           ['conv2d_165[0][0]']
#
#  batch_normalization_165 (Batch  (None, 8, 8, 64)    256         ['activation_165[0][0]']
#  Normalization)
#
#  conv2d_166 (Conv2D)            (None, 8, 8, 64)     36928       ['batch_normalization_165[0][0]']
#
#  activation_166 (Activation)    (None, 8, 8, 64)     0           ['conv2d_166[0][0]']
#
#  batch_normalization_166 (Batch  (None, 8, 8, 64)    256         ['activation_166[0][0]']
#  Normalization)
#
#  conv2d_167 (Conv2D)            (None, 8, 8, 64)     36928       ['batch_normalization_166[0][0]']
#
#  batch_normalization_167 (Batch  (None, 8, 8, 64)    256         ['conv2d_167[0][0]']
#  Normalization)
#
#  add_48 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_167[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  activation_167 (Activation)    (None, 8, 8, 64)     0           ['add_48[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_167[0][0]']
#
#  activation_168 (Activation)    (None, 8, 8, 64)     0           ['conv2d_168[0][0]']
#
#  batch_normalization_168 (Batch  (None, 8, 8, 64)    256         ['activation_168[0][0]']
#  Normalization)
#
#  conv2d_169 (Conv2D)            (None, 8, 8, 64)     36928       ['batch_normalization_168[0][0]']
#
#  activation_169 (Activation)    (None, 8, 8, 64)     0           ['conv2d_169[0][0]']
#
#  batch_normalization_169 (Batch  (None, 8, 8, 64)    256         ['activation_169[0][0]']
#  Normalization)
#
#  conv2d_170 (Conv2D)            (None, 8, 8, 64)     36928       ['batch_normalization_169[0][0]']
#
#  batch_normalization_170 (Batch  (None, 8, 8, 64)    256         ['conv2d_170[0][0]']
#  Normalization)
#
#  add_49 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_170[0][0]',
#                                                                   'activation_167[0][0]']
#
#  activation_170 (Activation)    (None, 8, 8, 64)     0           ['add_49[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_170[0][0]']
#
#  activation_171 (Activation)    (None, 8, 8, 64)     0           ['conv2d_171[0][0]']
#
#  batch_normalization_171 (Batch  (None, 8, 8, 64)    256         ['activation_171[0][0]']
#  Normalization)
#
#  conv2d_172 (Conv2D)            (None, 8, 8, 64)     36928       ['batch_normalization_171[0][0]']
#
#  activation_172 (Activation)    (None, 8, 8, 64)     0           ['conv2d_172[0][0]']
#
#  batch_normalization_172 (Batch  (None, 8, 8, 64)    256         ['activation_172[0][0]']
#  Normalization)
#
#  conv2d_173 (Conv2D)            (None, 8, 8, 64)     36928       ['batch_normalization_172[0][0]']
#
#  batch_normalization_173 (Batch  (None, 8, 8, 64)    256         ['conv2d_173[0][0]']
#  Normalization)
#
#  add_50 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_173[0][0]',
#                                                                   'activation_170[0][0]']
#
#  activation_173 (Activation)    (None, 8, 8, 64)     0           ['add_50[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 8, 8, 128)    73856       ['activation_173[0][0]']
#
#  activation_174 (Activation)    (None, 8, 8, 128)    0           ['conv2d_174[0][0]']
#
#  batch_normalization_174 (Batch  (None, 8, 8, 128)   512         ['activation_174[0][0]']
#  Normalization)
#
#  average_pooling2d_11 (AverageP  (None, 4, 4, 128)   0           ['batch_normalization_174[0][0]']
#  ooling2D)
#
#  dropout_9 (Dropout)            (None, 4, 4, 128)    0           ['average_pooling2d_11[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 4, 4, 128)    147584      ['dropout_9[0][0]']
#
#  activation_175 (Activation)    (None, 4, 4, 128)    0           ['conv2d_175[0][0]']
#
#  batch_normalization_175 (Batch  (None, 4, 4, 128)   512         ['activation_175[0][0]']
#  Normalization)
#
#  conv2d_176 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_175[0][0]']
#
#  activation_176 (Activation)    (None, 4, 4, 128)    0           ['conv2d_176[0][0]']
#
#  batch_normalization_176 (Batch  (None, 4, 4, 128)   512         ['activation_176[0][0]']
#  Normalization)
#
#  conv2d_177 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_176[0][0]']
#
#  batch_normalization_177 (Batch  (None, 4, 4, 128)   512         ['conv2d_177[0][0]']
#  Normalization)
#
#  add_51 (Add)                   (None, 4, 4, 128)    0           ['batch_normalization_177[0][0]',
#                                                                   'dropout_9[0][0]']
#
#  activation_177 (Activation)    (None, 4, 4, 128)    0           ['add_51[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_177[0][0]']
#
#  activation_178 (Activation)    (None, 4, 4, 128)    0           ['conv2d_178[0][0]']
#
#  batch_normalization_178 (Batch  (None, 4, 4, 128)   512         ['activation_178[0][0]']
#  Normalization)
#
#  conv2d_179 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_178[0][0]']
#
#  activation_179 (Activation)    (None, 4, 4, 128)    0           ['conv2d_179[0][0]']
#
#  batch_normalization_179 (Batch  (None, 4, 4, 128)   512         ['activation_179[0][0]']
#  Normalization)
#
#  conv2d_180 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_179[0][0]']
#
#  batch_normalization_180 (Batch  (None, 4, 4, 128)   512         ['conv2d_180[0][0]']
#  Normalization)
#
#  add_52 (Add)                   (None, 4, 4, 128)    0           ['batch_normalization_180[0][0]',
#                                                                   'activation_177[0][0]']
#
#  activation_180 (Activation)    (None, 4, 4, 128)    0           ['add_52[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_180[0][0]']
#
#  activation_181 (Activation)    (None, 4, 4, 128)    0           ['conv2d_181[0][0]']
#
#  batch_normalization_181 (Batch  (None, 4, 4, 128)   512         ['activation_181[0][0]']
#  Normalization)
#
#  conv2d_182 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_181[0][0]']
#
#  activation_182 (Activation)    (None, 4, 4, 128)    0           ['conv2d_182[0][0]']
#
#  batch_normalization_182 (Batch  (None, 4, 4, 128)   512         ['activation_182[0][0]']
#  Normalization)
#
#  conv2d_183 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_182[0][0]']
#
#  batch_normalization_183 (Batch  (None, 4, 4, 128)   512         ['conv2d_183[0][0]']
#  Normalization)
#
#  add_53 (Add)                   (None, 4, 4, 128)    0           ['batch_normalization_183[0][0]',
#                                                                   'activation_180[0][0]']
#
#  activation_183 (Activation)    (None, 4, 4, 128)    0           ['add_53[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 128)         0           ['activation_183[0][0]']
#  obalAveragePooling2D)
#
#  dense_4 (Dense)                (None, 10)           1290        ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 1,875,434
# Trainable params: 1,870,602
# Non-trainable params: 4,832
# __________________________________________________________________________________________________

# %%
width_shift = 3/32
height_shift = 3/32
flip = True

datagen = ImageDataGenerator(
    horizontal_flip=flip,
    width_shift_range=width_shift,
    height_shift_range=height_shift,
    )

# %%
# get data augmentation dataset
datagen.fit(train_dataset)

it = datagen.flow(train_dataset, y_train, shuffle=False)
batch_images, batch_labels = next(it)
visualize_data(batch_images, batch_labels, class_names)

# %% [markdown]
# # 5. Model Training
#
# We will now train the complied model on the cifar10 dataset using the tensorflow keras `model.fit` method.

# %%
# Adding a callback method to reduce the learning rate on a plateau of the LR.
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

# Add an early stopping callback with patience of 4.
early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %%
epochs =55

# Fitting model with larger batch size of 256.
history = model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, batch_size=256, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/55
# 1407/1407 [==============================] - 105s 74ms/step - loss: 1.4884 - accuracy: 0.6381 - val_loss: 1.6958 - val_accuracy: 0.5562 - lr: 0.0010
# Epoch 2/55
# 1407/1407 [==============================] - 105s 75ms/step - loss: 1.3426 - accuracy: 0.6808 - val_loss: 1.8034 - val_accuracy: 0.5553 - lr: 0.0010
# Epoch 3/55
# 1407/1407 [==============================] - 105s 75ms/step - loss: 1.2472 - accuracy: 0.7157 - val_loss: 1.4170 - val_accuracy: 0.6598 - lr: 0.0010
# Epoch 4/55
# 1407/1407 [==============================] - 107s 76ms/step - loss: 1.1595 - accuracy: 0.7429 - val_loss: 1.7591 - val_accuracy: 0.5898 - lr: 0.0010
# Epoch 5/55
# 1407/1407 [==============================] - 104s 74ms/step - loss: 1.0932 - accuracy: 0.7640 - val_loss: 1.3239 - val_accuracy: 0.6971 - lr: 0.0010
# Epoch 6/55
# 1407/1407 [==============================] - 105s 75ms/step - loss: 1.0297 - accuracy: 0.7858 - val_loss: 1.4264 - val_accuracy: 0.6682 - lr: 0.0010
# Epoch 7/55
# 1407/1407 [==============================] - 105s 75ms/step - loss: 0.9782 - accuracy: 0.8002 - val_loss: 1.5374 - val_accuracy: 0.6560 - lr: 0.0010
# Epoch 8/55
# 1407/1407 [==============================] - 105s 75ms/step - loss: 0.9428 - accuracy: 0.8164 - val_loss: 1.5922 - val_accuracy: 0.6376 - lr: 0.0010
# Epoch 9/55
# 1407/1407 [==============================] - 108s 77ms/step - loss: 0.9039 - accuracy: 0.8293 - val_loss: 1.3263 - val_accuracy: 0.7240 - lr: 0.0010
# Epoch 10/55
# 1407/1407 [==============================] - 108s 77ms/step - loss: 0.8724 - accuracy: 0.8382 - val_loss: 1.1501 - val_accuracy: 0.7516 - lr: 0.0010
# Epoch 11/55
# 1407/1407 [==============================] - 106s 76ms/step - loss: 0.8389 - accuracy: 0.8518 - val_loss: 1.3296 - val_accuracy: 0.7202 - lr: 0.0010
# Epoch 12/55
# 1407/1407 [==============================] - 106s 76ms/step - loss: 0.8142 - accuracy: 0.8602 - val_loss: 1.3020 - val_accuracy: 0.7353 - lr: 0.0010
# Epoch 13/55
# 1407/1407 [==============================] - 107s 76ms/step - loss: 0.7842 - accuracy: 0.8692 - val_loss: 1.1897 - val_accuracy: 0.7656 - lr: 0.0010
# Epoch 14/55
# 1407/1407 [==============================] - 106s 75ms/step - loss: 0.7586 - accuracy: 0.8775 - val_loss: 1.2384 - val_accuracy: 0.7642 - lr: 0.0010
# Epoch 15/55
# 1407/1407 [==============================] - 106s 76ms/step - loss: 0.7399 - accuracy: 0.8837 - val_loss: 1.2304 - val_accuracy: 0.7642 - lr: 0.0010
# Epoch 16/55
# 1407/1407 [==============================] - 107s 76ms/step - loss: 0.7098 - accuracy: 0.8939 - val_loss: 1.3958 - val_accuracy: 0.7304 - lr: 0.0010
# Epoch 17/55
# 1407/1407 [==============================] - 106s 75ms/step - loss: 0.6956 - accuracy: 0.9012 - val_loss: 1.2525 - val_accuracy: 0.7613 - lr: 0.0010
# Epoch 18/55
# 1407/1407 [==============================] - 106s 76ms/step - loss: 0.6844 - accuracy: 0.9040 - val_loss: 1.4368 - val_accuracy: 0.7358 - lr: 0.0010
# Epoch 19/55
# 1407/1407 [==============================] - 105s 75ms/step - loss: 0.6620 - accuracy: 0.9117 - val_loss: 1.7074 - val_accuracy: 0.6989 - lr: 0.0010
# Epoch 20/55
# 1008/1407 [====================>.........] - ETA: 6:12 - loss: 0.6411 - accuracy: 0.9162

# %% [markdown]
# We will plot the loss and accuracy for the training and validation data sets.

# %%
print(history.history.keys())
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # 6. Model Testing
# We will iterate through the test data and analyse the results using tools from sklearn. We create a classification report, a confusion matrix and also plot a few examples from the test set.

# %% [markdown]
# Iterate through n_test batches and store the predicted and ground truth labels in numpy arrays.

# %%
n_test = 100 # number of batches to use
store_predictions = []
store_labels = []
for image_batch,label_batch in test_dataset.take(n_test):
    predictions = model.predict_on_batch(image_batch) 
    predictions = tf.math.argmax(predictions,axis=1)
    store_predictions.append(predictions)
    store_labels.append(label_batch)
y_pred = np.squeeze(np.reshape(store_predictions,(1,n_test*batch_size)))
y_true = np.squeeze(np.reshape(store_labels,(1,n_test*batch_size)))

# %% [markdown]
# Create and plot a confusion matrix.

# %%
#https://scikit-learn.org/0.16/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_str))
    plt.xticks(tick_marks, label_str, rotation=45)
    plt.yticks(tick_marks, label_str)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm)

# %% [markdown]
# Generate & print the classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=label_str))

# %% [markdown]
# Plot some test images and predicted labels.

# %%
#Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)
print(np.shape(predictions))
# Apply a sigmoid since our model returns logits
predictions = tf.math.argmax(predictions,axis=1)
print(np.shape(predictions))
print('Predictions:\n', predictions.numpy())


i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image in image_batch[0:n_plots,:,:,:]:  # Only take a single example
  axarr[i].imshow(image[:,:,:]+0.5)
  axarr[i].axis('off')
  
  color = ('black' if predictions[i] == int(label_batch[i]) else 'red') 
  axarr[i].set_title(label_str[int(predictions[i])],fontsize='small', color=color)
  i = i+1

# %% [markdown]
# # Please Leave a note here explaining your approach/results for the e-moderator.
