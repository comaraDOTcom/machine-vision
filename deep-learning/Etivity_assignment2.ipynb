# %% [markdown]
# <a href="https://colab.research.google.com/github/comaraDOTcom/machine-vision/blob/main/deep-learning/Etivity_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Etivity 2
# Name: Conor O'Mara
# Student number: 20151845

# %% [markdown]
# # Etivity 2: Deep Convolutional Neural Network on CIFAR-10 Dataset
#
# In this assignment, we will gain some practical experience of coding a deep convolutional neural network in Tensorflow. The simplest way to code a network is to use the High level Keras API within Tensorflow 2.5.
#
# ## (a) Introduction
#
#  In this assignment to reduce training time and computation, we will train our network using the simple [CIFAR10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset.
# ![link text](https://paperswithcode.com/media/datasets/CIFAR-10-0000000431-b71f61c0_U5n3Glr.jpg)
#
# The goal of this Etivity is to build and train your own Deep Convolutional Neural Network. This notebook contains standard keras/Tensorflow code to perform data processing, training set up and testing metrics, as outlined in the steps below. This will allow you to focus on developing the architecture & code for your network.
#
# 1. Load Dataset - We will import the CIFAR-10 Dataset using the Tensorflow Data Set API.
# 2. Prepare Data - We will slightly modify the dataset before it is sent to the model for training.
# 3. Model Coding - We will write code to build the model using the Tensorflow keras API.
#   * **You will code your neural network model in this section**
# 4. Compile Model - We will compile the model and verify that it has been correctly constructed.
# 5. Train Model - We will train the model using the imported dataset.
# 6. Test Model - We test the model on the training data and obtain a classification report and confusion matrix.
#
# The principal resource for understanding the basics of how to code & train Deep Convolutional Neural Network architectures in Tensorflow/keras are the Tensorflow tutorials. Tutorials on [image classification](https://www.tensorflow.org/tutorials/images/classification) and [data augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation) are useful for this Etivity.

# %% [markdown]
# ## (b) Notes on Architecture selection & development
#
# A key task in this Etivity is selecting an appropriate architecture. You can base your archicture on any of the types seen in the lecture notes or published literature. It is however recommended to ensure you can get a standard CNN type architecture to successfully train before attempting a more complex architecture or adding further enhancements to your network to improve performance.
#    Many published networks are designed to work with larger sized input images (e.g. 224 x 224). Often large (e.g. 7 x 7) convolution kernels and pooling layers are first applied to the input image, which agressively reduce the spatial dimensions of the network. As the CIFAR-10 dataset only has 32 x 32 images, it is recommended that just an intial 3 x 3 convolution is applied to the input image (as shown in the figure below), which will preserve the spatial dimensions of the input, before any other layers are added. It is expected that as you add more layers to the network the spatial dimensions will reduce and there will also be a corresponding increase the number of channels of the output feature map. The architecture will end with a [global average pooling layer](https://arxiv.org/pdf/1312.4400.pdf) and a fully-connected layer (called a *dense* layer in Keras/Tensorflow) with softmax activation which gives us our 10 class predictions. A skeleton code has been provided for any general architure using this structure in section 3.
# ![link text](https://github.com/tonyscan6003/CE6003/blob/master/images/Architecture_outline.jpg?raw=true)

# %% [markdown]
# #House Keeping

# %%
from __future__ import print_function

# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, RandomFlip, RandomTranslation, RandomZoom
from tensorflow.keras.layers import GlobalAveragePooling2D, AveragePooling2D, Input, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import cifar10

import numpy as np

# %% [markdown]
# To ensure this assignment runs as fast as possible, from the menu above select **Edit > Notebook settings** or **Runtime > Change runtime type** and select GPU as the Hardware accelerator option.
#
# Let's test that we are running using the GPU.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# #1. Load Dataset
#
# In this assignment, we will be using the [CIFAR-10 dataset](http://www.cs.toronto.edu/~kriz/cifar.htmlhttps://). CIFAR-10 is often used as a "Hello World" dataset that is often used to ensure a network architecture is working before moving on to training with more complex datasets.
#
# The CIFAR-10 dataset consists of 60,000 32x32 color images in 10 classes (airplane, automobile, **bird**, cat, deer, dog, frog, horse, ship, truck), with 6,000 images per class. There are 50,000 training images and 10,000 test images.
#
# We will use the [Tensorflow dataset](https://www.tensorflow.org/datasets/catalog/cifar10) API to download the CIFAR10 dataset.

# %%
batch_size = 32 # Default Batch size (can be adjusted)
H_trg =32       # Image Height (fixed)
W_trg =32       # image Width (fixed)

# Labels corresponding to categories
label_str = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# We initally load the raw training/validation/test dataset
import tensorflow_datasets as tfds
ds,info= tfds.load("cifar10",with_info=True)

raw_train = tfds.load('cifar10', split='train[0%:90%]')
raw_val = tfds.load('cifar10', split='train[91%:100%]')
raw_test = tfds.load('cifar10', split='test')
# Out:
# Downloading and preparing dataset cifar10/3.0.2 (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incomplete3BP038/cifar10-train.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incomplete3BP038/cifar10-test.tfrecord
#   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# # 2. Prepare Data
#
# After importing raw datasets using tfds load, we create an input pipeline that processes & batches this data before it is supplied to the model for training using the virtual machine GPU.

# %%
def data_pipe(image,label):
  image = tf.image.convert_image_dtype(image, tf.float32) # Cast and normalize the image to [0,1]
  image = image-0.5
  label = tf.cast(label, tf.float32)
  return image,label

# %%
def gen_tr_datasets(src_dataset):    
    # Define Datasets 
    #src_dataset = src_dataset.shuffle(num_train_examples) 
    tr_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    tr_dataset = tr_dataset.map(data_pipe)
    tr_dataset = tr_dataset.batch(batch_size) 
    return tr_dataset

def gen_val_datasets(src_dataset): 
    # Define Datasets 
    test_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    test_dataset = test_dataset.map(data_pipe)
    test_dataset = test_dataset.batch(batch_size) 
    return test_dataset
# Generate the datasets
train_dataset = gen_tr_datasets(raw_train)
val_dataset = gen_val_datasets(raw_val)
test_dataset = gen_val_datasets(raw_test)

# %% [markdown]
# Plot some examples of the training dataset.

# %%
# plot training examples
i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image, label in train_dataset.take(n_plots):  # Only take a single example
  axarr[i].imshow(image[0,:,:,:]+0.5)
  axarr[i].axis('off')
  axarr[i].title.set_text(label_str[int(label[0])])
  i = i+1

# %% [markdown]
# # 3. Model Coding
#
# In this section You may develop your own model architecture to perform image recognition with the CIFAR-10 Dataset.
#
# There are some recommendations and helper code in this section that you may choose use, or you can also use your own approach to creating your architecture.
#
# Please Leave a note at the end of the notebook explaining your approach/results for the e-moderator.

# %% [markdown]
#
# ## Note 1: Keras Function/Sequential API
#
# Within Keras there are two API's for coding network models: Sequential and functional. You may have already used the [seqential model](https://https://www.tensorflow.org/guide/keras/sequential_model) to code basic artifical neural networks. The [functional model](https://www.tensorflow.org/guide/keras/functional) is more general and enables us to include feedforward paths which are required to code more advanced networks such as ResNet or DenseNet. The functional API has been used to code the helper functions repeating unit/top level skeleton detailed below.
#
# ## Note 2: Repeating Unit
#
# In many Deep architectures there will often be a repeating unit(s) that is composed of a sequence of layers, for example Conv,ReLU & Batch Normalisation. Specific layers can be turned on or off as required. This also allows experimentation of the entire architecture with/without specific layers (e.g. Batch Normalisation)  You may wish to create other combinations of layers or additional repeating units depending on your architecture.
#
# In the code cell below we can see an example of a `repeat_unit` function where the number of kernel filters and kernel size is specified. Batch Normalisation and activation layers can be turned on/off as required.
#
#  * Convolutional Layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
#  * Batch Normalization layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization)
#  * Activation layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Activation)

# %%
# Example of a Basic Repeating unit

def repeat_unit(inputs, num_channels=16, kernel_size=3,
                 strides=1, activation='relu', batch_normalization=False, avg_pooling=False, dropout=None , kernel_regularizer=None):
    """
    inputs: Input to repeat unit.
    num_channels: number of channels in convolution layer of repeat unit, nominally = 16
    kernel_size: number of kernels to use in convolution, nominally = 3
    strides: number of strides for kernel, nominally = 1
    activation: type of activation applied to output of convolution, nominally ReLU. 
    x = output of repeat_unit
    """
    conv = Conv2D(num_channels, kernel_size=kernel_size, strides=strides, padding='same',
                  kernel_initializer='he_normal', kernel_regularizer=kernel_regularizer)
    x = conv(inputs)
    
    if activation is not None:
        x = Activation(activation)(x)

    if batch_normalization:
        x = BatchNormalization()(x)

    if avg_pooling:
        x = AveragePooling2D(pool_size=(2,2))(x)

    if dropout is not None:
        x = Dropout(dropout)(x) 

    return x

# %%
def resnet_block(inputs, num_channels=16, kernel_size=3):
  """
  Resnet block that has 3 repeat units all with 
  """

  x_shortcut = inputs # Store the initial value of X in a variable
  ## P3 repeat units 
  x = repeat_unit(inputs, num_channels=num_channels, kernel_size=kernel_size, strides = 1, activation=None, batch_normalization=True, kernel_regularizer='l1')
  x = repeat_unit(x, num_channels=num_channels, kernel_size=kernel_size, strides = 1, activation=None, batch_normalization=True)
  x = repeat_unit(x, num_channels=num_channels, kernel_size=kernel_size, strides = 1, activation=None, batch_normalization=True)
  
  x = keras.layers.Add()([x, x_shortcut]) # SKIP Connection

  x = Activation('relu')(x)
  return x

# %% [markdown]
# ## Note 3: Top Level
#
# In the code cell below, an incomplete skeleton function is provided for your top level.
# * This uses the Keras functional API
# * A single repeating unit which does not reduce the spatial dimensions of the input is placed at the top of the stack. You can change the number of channels/kernel size to suit your own architecture.
# * You can add your own layers/repeating units etc to build your own architecture with the function.
# * At the end of the stack we add a [global average pooling layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling2D) and fully connected [(Dense)](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) layer with softmax activation. (Alternatively to the Global Average pooling Dense layers can be used, this approach uses more parameter (memory) and is commonly seen in earlier Deeep Learning architectures such as AlexNet)

# %%
def network_top(input_shape,num_classes=10):
    """
    input Shape: (Define H,W, no. channels) of network input
                 used in Input definition below
    num_classes: Default = 10, sets output classes of network,
                 set to same no. of classes as CIFAR 10 Dataset 
    model:       keras Model returned by this function.                          
    """
       
    # Define input of model
    inputs = Input(shape=input_shape)

    data_augmentation = tf.keras.Sequential([RandomTranslation(0.1, 0.1, fill_mode='nearest'), RandomFlip("horizontal")])
    x = tf.keras.Sequential(data_augmentation)(inputs)

    # Add First repeating Unit
    x = repeat_unit(x, num_channels=16, batch_normalization=True)
    for i in range(0,3):
      x = resnet_block(x, num_channels=16)
      
    x = repeat_unit(x, num_channels=32, batch_normalization=True,  avg_pooling=False)
    for i in range(0,3):
      x = resnet_block(x, num_channels=32)

    x = repeat_unit(x, num_channels=64, batch_normalization=True,  avg_pooling=False, kernel_regularizer='l1')
    for i in range(0,3):
      x = resnet_block(x, num_channels=64)

    x = AveragePooling2D(pool_size=8)(x)
    x = Flatten()(x)
    x = BatchNormalization()(x)

    # Output Layer
    outputs = Dense(num_classes, activation='softmax', kernel_initializer='he_normal')(x)

    # Model definition
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # 4. Compile the Model
# Now that we have defined our functions to create the model, we'll instantiate the model and compile it.  Note that the compiling step in Keras, also configures the model for training. We define  loss function, the optimizer and metrics.
#
# Note the use here of [Sparse Categorical Crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy). This loss function allows us to input integer values for true classes. With the regular categorical cross entropy loss function the supplied labels must be frist converted to a one-hot representation,  but this special loss function allows us to avoid manually converting to the one-hot representation.

# %%
input_shape = (32,32,3)
model = network_top(input_shape=input_shape)
model.compile(loss='SparseCategoricalCrossentropy', optimizer=Adam(), metrics=['accuracy'])
model.summary()

# Plot the model visually
keras.utils.plot_model(model, dpi=60)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  sequential_3 (Sequential)      (None, 32, 32, 3)    0           ['input_2[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 16)   448         ['sequential_3[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 16)   0           ['conv2d_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 16)  64          ['activation_12[0][0]']
#  ormalization)
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 16)  64          ['conv2d_31[0][0]']
#  ormalization)
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 16)  64          ['conv2d_32[0][0]']
#  ormalization)
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 16)  64          ['conv2d_33[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 32, 32, 16)   0           ['batch_normalization_34[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['add_9[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 32, 32, 16)  64          ['conv2d_34[0][0]']
#  ormalization)
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 16)  64          ['conv2d_35[0][0]']
#  ormalization)
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 16)  64          ['conv2d_36[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_37[0][0]',
#                                                                   'activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['add_10[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_14[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 16)  64          ['conv2d_37[0][0]']
#  ormalization)
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 16)  64          ['conv2d_38[0][0]']
#  ormalization)
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 16)  64          ['conv2d_39[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_40[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 32, 32, 16)   0           ['add_11[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 32)   4640        ['activation_15[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 32)   0           ['conv2d_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 32)  128         ['activation_16[0][0]']
#  ormalization)
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 32, 32, 32)  128         ['conv2d_41[0][0]']
#  ormalization)
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 32)  128         ['conv2d_42[0][0]']
#  ormalization)
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 32, 32, 32)  128         ['conv2d_43[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 32, 32, 32)   0           ['batch_normalization_44[0][0]',
#                                                                   'batch_normalization_41[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 32)   0           ['add_12[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_17[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 32)  128         ['conv2d_44[0][0]']
#  ormalization)
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 32)  128         ['conv2d_45[0][0]']
#  ormalization)
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 32)  128         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 32, 32, 32)   0           ['batch_normalization_47[0][0]',
#                                                                   'activation_17[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 32)   0           ['add_13[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_18[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 32)  128         ['conv2d_47[0][0]']
#  ormalization)
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 32)  128         ['conv2d_48[0][0]']
#  ormalization)
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 32, 32, 32)  128         ['conv2d_49[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 32, 32, 32)   0           ['batch_normalization_50[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_19 (Activation)     (None, 32, 32, 32)   0           ['add_14[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 64)   18496       ['activation_19[0][0]']
#
#  activation_20 (Activation)     (None, 32, 32, 64)   0           ['conv2d_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 32, 32, 64)  256         ['activation_20[0][0]']
#  ormalization)
#
#  conv2d_51 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 32, 32, 64)  256         ['conv2d_51[0][0]']
#  ormalization)
#
#  conv2d_52 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 32, 32, 64)  256         ['conv2d_52[0][0]']
#  ormalization)
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 32, 32, 64)  256         ['conv2d_53[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_54[0][0]',
#                                                                   'batch_normalization_51[0][0]']
#
#  activation_21 (Activation)     (None, 32, 32, 64)   0           ['add_15[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_21[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 32, 32, 64)  256         ['conv2d_54[0][0]']
#  ormalization)
#
#  conv2d_55 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 32, 32, 64)  256         ['conv2d_55[0][0]']
#  ormalization)
#
#  conv2d_56 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 32, 32, 64)  256         ['conv2d_56[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_57[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 32, 32, 64)   0           ['add_16[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_22[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 32, 32, 64)  256         ['conv2d_57[0][0]']
#  ormalization)
#
#  conv2d_58 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 32, 32, 64)  256         ['conv2d_58[0][0]']
#  ormalization)
#
#  conv2d_59 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_59[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 32, 32, 64)  256         ['conv2d_59[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_60[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_23 (Activation)     (None, 32, 32, 64)   0           ['add_17[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 4, 4, 64)    0           ['activation_23[0][0]']
#  oling2D)
#
#  flatten_1 (Flatten)            (None, 1024)         0           ['average_pooling2d_1[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 1024)        4096        ['flatten_1[0][0]']
#  ormalization)
#
#  dense_1 (Dense)                (None, 10)           10250       ['batch_normalization_61[0][0]']
#
# ==================================================================================================
# Total params: 478,874
# Trainable params: 474,586
# Non-trainable params: 4,288
# __________________________________________________________________________________________________

# %% [markdown]
# # 5. Model Training
#
# We will now train the complied model on the cifar10 dataset using the tensorflow keras `model.fit` method.

# %%
# Adding a callback method to reduce the learning rate on a plateau of the LR.
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, min_lr=0.000001)

# Add an early stopping callback with patience of 4.
early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=6)

# %%
epochs =125

# Fitting model with larger batch size of 256.
history = model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, batch_size=32, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/125
# 1407/1407 [==============================] - 48s 32ms/step - loss: 7.7196 - accuracy: 0.3656 - val_loss: 3.1723 - val_accuracy: 0.3218 - lr: 0.0010
# Epoch 2/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 2.7163 - accuracy: 0.4662 - val_loss: 9.7366 - val_accuracy: 0.1882 - lr: 0.0010
# Epoch 3/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 2.3527 - accuracy: 0.5323 - val_loss: 2.1494 - val_accuracy: 0.5638 - lr: 0.0010
# Epoch 4/125
# 1407/1407 [==============================] - 43s 30ms/step - loss: 2.0865 - accuracy: 0.5740 - val_loss: 2.6566 - val_accuracy: 0.4458 - lr: 0.0010
# Epoch 5/125
# 1407/1407 [==============================] - 43s 30ms/step - loss: 1.9262 - accuracy: 0.6017 - val_loss: 2.3268 - val_accuracy: 0.4978 - lr: 0.0010
# Epoch 6/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.8016 - accuracy: 0.6150 - val_loss: 2.6292 - val_accuracy: 0.4616 - lr: 0.0010
# Epoch 7/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.6934 - accuracy: 0.6319 - val_loss: 1.8555 - val_accuracy: 0.6096 - lr: 0.0010
# Epoch 8/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.6392 - accuracy: 0.6455 - val_loss: 1.7154 - val_accuracy: 0.6313 - lr: 0.0010
# Epoch 9/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.5794 - accuracy: 0.6553 - val_loss: 1.5791 - val_accuracy: 0.6564 - lr: 0.0010
# Epoch 10/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.5233 - accuracy: 0.6649 - val_loss: 1.6632 - val_accuracy: 0.6489 - lr: 0.0010
# Epoch 11/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.4773 - accuracy: 0.6767 - val_loss: 1.5658 - val_accuracy: 0.6691 - lr: 0.0010
# Epoch 12/125
# 1407/1407 [==============================] - 43s 30ms/step - loss: 1.4480 - accuracy: 0.6811 - val_loss: 1.7815 - val_accuracy: 0.6118 - lr: 0.0010
# Epoch 13/125
# 1407/1407 [==============================] - 43s 30ms/step - loss: 1.4130 - accuracy: 0.6908 - val_loss: 1.7354 - val_accuracy: 0.6302 - lr: 0.0010
# Epoch 14/125
# 1407/1407 [==============================] - 43s 30ms/step - loss: 1.3866 - accuracy: 0.6956 - val_loss: 1.7300 - val_accuracy: 0.6304 - lr: 0.0010
# Epoch 15/125
# 1407/1407 [==============================] - 43s 30ms/step - loss: 1.3674 - accuracy: 0.7009 - val_loss: 1.3466 - val_accuracy: 0.7131 - lr: 0.0010
# Epoch 16/125
# 1407/1407 [==============================] - 43s 30ms/step - loss: 1.3389 - accuracy: 0.7077 - val_loss: 1.9575 - val_accuracy: 0.6049 - lr: 0.0010
# Epoch 17/125
# 1407/1407 [==============================] - 43s 30ms/step - loss: 1.3252 - accuracy: 0.7108 - val_loss: 1.7555 - val_accuracy: 0.6231 - lr: 0.0010
# Epoch 18/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.3019 - accuracy: 0.7160 - val_loss: 1.4507 - val_accuracy: 0.6924 - lr: 0.0010
# Epoch 19/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.2886 - accuracy: 0.7162 - val_loss: 1.3268 - val_accuracy: 0.7198 - lr: 0.0010
# Epoch 20/125
# 1407/1407 [==============================] - 44s 32ms/step - loss: 1.2706 - accuracy: 0.7227 - val_loss: 1.2967 - val_accuracy: 0.7229 - lr: 0.0010
# Epoch 21/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.2582 - accuracy: 0.7241 - val_loss: 1.2828 - val_accuracy: 0.7360 - lr: 0.0010
# Epoch 22/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.2453 - accuracy: 0.7281 - val_loss: 1.2398 - val_accuracy: 0.7353 - lr: 0.0010
# Epoch 23/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.2320 - accuracy: 0.7316 - val_loss: 1.4478 - val_accuracy: 0.6942 - lr: 0.0010
# Epoch 24/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.2260 - accuracy: 0.7336 - val_loss: 2.0727 - val_accuracy: 0.5931 - lr: 0.0010
# Epoch 25/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.2152 - accuracy: 0.7367 - val_loss: 1.3065 - val_accuracy: 0.7144 - lr: 0.0010
# Epoch 26/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.2087 - accuracy: 0.7382 - val_loss: 1.3637 - val_accuracy: 0.7078 - lr: 0.0010
# Epoch 27/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.1939 - accuracy: 0.7399 - val_loss: 1.2451 - val_accuracy: 0.7411 - lr: 0.0010
# Epoch 28/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.1172 - accuracy: 0.7463 - val_loss: 1.1448 - val_accuracy: 0.7462 - lr: 8.0000e-04
# Epoch 29/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.0999 - accuracy: 0.7498 - val_loss: 1.2043 - val_accuracy: 0.7320 - lr: 8.0000e-04
# Epoch 30/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.0978 - accuracy: 0.7516 - val_loss: 1.1047 - val_accuracy: 0.7536 - lr: 8.0000e-04
# Epoch 31/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.0848 - accuracy: 0.7534 - val_loss: 1.5248 - val_accuracy: 0.6620 - lr: 8.0000e-04
# Epoch 32/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.0802 - accuracy: 0.7549 - val_loss: 1.1586 - val_accuracy: 0.7440 - lr: 8.0000e-04
# Epoch 33/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.0811 - accuracy: 0.7554 - val_loss: 1.3641 - val_accuracy: 0.6947 - lr: 8.0000e-04
# Epoch 34/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.0820 - accuracy: 0.7557 - val_loss: 1.3749 - val_accuracy: 0.6909 - lr: 8.0000e-04
# Epoch 35/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.0773 - accuracy: 0.7563 - val_loss: 1.2701 - val_accuracy: 0.7131 - lr: 8.0000e-04
# Epoch 36/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.0097 - accuracy: 0.7649 - val_loss: 1.0505 - val_accuracy: 0.7598 - lr: 6.4000e-04
# Epoch 37/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 1.0062 - accuracy: 0.7635 - val_loss: 1.0647 - val_accuracy: 0.7509 - lr: 6.4000e-04
# Epoch 38/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.9904 - accuracy: 0.7653 - val_loss: 1.0652 - val_accuracy: 0.7584 - lr: 6.4000e-04
# Epoch 39/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.9886 - accuracy: 0.7692 - val_loss: 1.3820 - val_accuracy: 0.6747 - lr: 6.4000e-04
# Epoch 40/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.9904 - accuracy: 0.7676 - val_loss: 1.1651 - val_accuracy: 0.7322 - lr: 6.4000e-04
# Epoch 41/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.9859 - accuracy: 0.7703 - val_loss: 1.0717 - val_accuracy: 0.7533 - lr: 6.4000e-04
# Epoch 42/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.9288 - accuracy: 0.7708 - val_loss: 0.9970 - val_accuracy: 0.7631 - lr: 5.1200e-04
# Epoch 43/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.9292 - accuracy: 0.7748 - val_loss: 0.9637 - val_accuracy: 0.7702 - lr: 5.1200e-04
# Epoch 44/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.9143 - accuracy: 0.7762 - val_loss: 0.9815 - val_accuracy: 0.7642 - lr: 5.1200e-04
# Epoch 45/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.9213 - accuracy: 0.7777 - val_loss: 1.0739 - val_accuracy: 0.7447 - lr: 5.1200e-04
# Epoch 46/125
# 1407/1407 [==============================] - 44s 32ms/step - loss: 0.9142 - accuracy: 0.7772 - val_loss: 0.9943 - val_accuracy: 0.7631 - lr: 5.1200e-04
# Epoch 47/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.9096 - accuracy: 0.7790 - val_loss: 1.1588 - val_accuracy: 0.7271 - lr: 5.1200e-04
# Epoch 48/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.9167 - accuracy: 0.7779 - val_loss: 1.0652 - val_accuracy: 0.7556 - lr: 5.1200e-04
# Epoch 49/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8623 - accuracy: 0.7806 - val_loss: 0.8807 - val_accuracy: 0.7884 - lr: 4.0960e-04
# Epoch 50/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8595 - accuracy: 0.7838 - val_loss: 0.9716 - val_accuracy: 0.7669 - lr: 4.0960e-04
# Epoch 51/125
# 1407/1407 [==============================] - 44s 32ms/step - loss: 0.8589 - accuracy: 0.7848 - val_loss: 0.8936 - val_accuracy: 0.7851 - lr: 4.0960e-04
# Epoch 52/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8569 - accuracy: 0.7840 - val_loss: 1.0437 - val_accuracy: 0.7473 - lr: 4.0960e-04
# Epoch 53/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8549 - accuracy: 0.7818 - val_loss: 1.0031 - val_accuracy: 0.7464 - lr: 4.0960e-04
# Epoch 54/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8584 - accuracy: 0.7859 - val_loss: 1.2598 - val_accuracy: 0.6969 - lr: 4.0960e-04
# Epoch 55/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8084 - accuracy: 0.7886 - val_loss: 0.8890 - val_accuracy: 0.7760 - lr: 3.2768e-04
# Epoch 56/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.8136 - accuracy: 0.7903 - val_loss: 0.8451 - val_accuracy: 0.7871 - lr: 3.2768e-04
# Epoch 57/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8113 - accuracy: 0.7889 - val_loss: 0.9981 - val_accuracy: 0.7429 - lr: 3.2768e-04
# Epoch 58/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8044 - accuracy: 0.7908 - val_loss: 0.9953 - val_accuracy: 0.7567 - lr: 3.2768e-04
# Epoch 59/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.8049 - accuracy: 0.7903 - val_loss: 0.9014 - val_accuracy: 0.7716 - lr: 3.2768e-04
# Epoch 60/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8035 - accuracy: 0.7908 - val_loss: 0.9051 - val_accuracy: 0.7793 - lr: 3.2768e-04
# Epoch 61/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.8054 - accuracy: 0.7903 - val_loss: 0.9373 - val_accuracy: 0.7722 - lr: 3.2768e-04
# Epoch 62/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.7715 - accuracy: 0.7941 - val_loss: 0.8689 - val_accuracy: 0.7716 - lr: 2.6214e-04
# Epoch 63/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.7651 - accuracy: 0.7961 - val_loss: 0.9926 - val_accuracy: 0.7411 - lr: 2.6214e-04
# Epoch 64/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.7633 - accuracy: 0.7958 - val_loss: 0.8298 - val_accuracy: 0.7907 - lr: 2.6214e-04
# Epoch 65/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.7652 - accuracy: 0.7954 - val_loss: 0.8950 - val_accuracy: 0.7602 - lr: 2.6214e-04
# Epoch 66/125
# 1407/1407 [==============================] - 44s 32ms/step - loss: 0.7657 - accuracy: 0.7953 - val_loss: 0.8802 - val_accuracy: 0.7738 - lr: 2.6214e-04
# Epoch 67/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.7609 - accuracy: 0.7960 - val_loss: 0.7968 - val_accuracy: 0.7949 - lr: 2.6214e-04
# Epoch 68/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7579 - accuracy: 0.7973 - val_loss: 0.7916 - val_accuracy: 0.7951 - lr: 2.6214e-04
# Epoch 69/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.7574 - accuracy: 0.7944 - val_loss: 0.8488 - val_accuracy: 0.7858 - lr: 2.6214e-04
# Epoch 70/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7587 - accuracy: 0.7984 - val_loss: 0.8625 - val_accuracy: 0.7778 - lr: 2.6214e-04
# Epoch 71/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7545 - accuracy: 0.7997 - val_loss: 0.8145 - val_accuracy: 0.7884 - lr: 2.6214e-04
# Epoch 72/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7581 - accuracy: 0.7967 - val_loss: 0.7825 - val_accuracy: 0.7911 - lr: 2.6214e-04
# Epoch 73/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7602 - accuracy: 0.7957 - val_loss: 0.8120 - val_accuracy: 0.7929 - lr: 2.6214e-04
# Epoch 74/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.7556 - accuracy: 0.7995 - val_loss: 0.7991 - val_accuracy: 0.7918 - lr: 2.6214e-04
# Epoch 75/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7541 - accuracy: 0.7986 - val_loss: 0.8790 - val_accuracy: 0.7691 - lr: 2.6214e-04
# Epoch 76/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7547 - accuracy: 0.7988 - val_loss: 0.8265 - val_accuracy: 0.7887 - lr: 2.6214e-04
# Epoch 77/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.7579 - accuracy: 0.7985 - val_loss: 0.8464 - val_accuracy: 0.7849 - lr: 2.6214e-04
# Epoch 78/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7282 - accuracy: 0.8000 - val_loss: 0.7745 - val_accuracy: 0.7976 - lr: 2.0972e-04
# Epoch 79/125
# 1407/1407 [==============================] - 43s 31ms/step - loss: 0.7238 - accuracy: 0.8010 - val_loss: 0.8026 - val_accuracy: 0.7853 - lr: 2.0972e-04
# Epoch 80/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7226 - accuracy: 0.8033 - val_loss: 0.8089 - val_accuracy: 0.7898 - lr: 2.0972e-04
# Epoch 81/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7242 - accuracy: 0.8012 - val_loss: 0.8589 - val_accuracy: 0.7678 - lr: 2.0972e-04
# Epoch 82/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7256 - accuracy: 0.8022 - val_loss: 0.7946 - val_accuracy: 0.7889 - lr: 2.0972e-04
# Epoch 83/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7239 - accuracy: 0.8022 - val_loss: 0.7663 - val_accuracy: 0.7929 - lr: 2.0972e-04
# Epoch 84/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7202 - accuracy: 0.8025 - val_loss: 0.8400 - val_accuracy: 0.7789 - lr: 2.0972e-04
# Epoch 85/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.7184 - accuracy: 0.8049 - val_loss: 0.8854 - val_accuracy: 0.7678 - lr: 2.0972e-04
# Epoch 86/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7164 - accuracy: 0.8056 - val_loss: 0.8484 - val_accuracy: 0.7773 - lr: 2.0972e-04
# Epoch 87/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7179 - accuracy: 0.8039 - val_loss: 0.8102 - val_accuracy: 0.7851 - lr: 2.0972e-04
# Epoch 88/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.7176 - accuracy: 0.8031 - val_loss: 0.7936 - val_accuracy: 0.7896 - lr: 2.0972e-04
# Epoch 89/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.6971 - accuracy: 0.8063 - val_loss: 0.7658 - val_accuracy: 0.7887 - lr: 1.6777e-04
# Epoch 90/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.6926 - accuracy: 0.8080 - val_loss: 0.7606 - val_accuracy: 0.7951 - lr: 1.6777e-04
# Epoch 91/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6918 - accuracy: 0.8064 - val_loss: 0.7443 - val_accuracy: 0.8027 - lr: 1.6777e-04
# Epoch 92/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6931 - accuracy: 0.8079 - val_loss: 0.7560 - val_accuracy: 0.7942 - lr: 1.6777e-04
# Epoch 93/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6945 - accuracy: 0.8050 - val_loss: 0.8089 - val_accuracy: 0.7813 - lr: 1.6777e-04
# Epoch 94/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6903 - accuracy: 0.8072 - val_loss: 0.7048 - val_accuracy: 0.8040 - lr: 1.6777e-04
# Epoch 95/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6886 - accuracy: 0.8082 - val_loss: 0.7721 - val_accuracy: 0.7918 - lr: 1.6777e-04
# Epoch 96/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6886 - accuracy: 0.8078 - val_loss: 0.7716 - val_accuracy: 0.7958 - lr: 1.6777e-04
# Epoch 97/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6882 - accuracy: 0.8080 - val_loss: 0.7579 - val_accuracy: 0.7942 - lr: 1.6777e-04
# Epoch 98/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6898 - accuracy: 0.8075 - val_loss: 0.7743 - val_accuracy: 0.7918 - lr: 1.6777e-04
# Epoch 99/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6891 - accuracy: 0.8070 - val_loss: 0.7804 - val_accuracy: 0.7889 - lr: 1.6777e-04
# Epoch 100/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6706 - accuracy: 0.8082 - val_loss: 0.7887 - val_accuracy: 0.7833 - lr: 1.3422e-04
# Epoch 101/125
# 1407/1407 [==============================] - 46s 33ms/step - loss: 0.6662 - accuracy: 0.8077 - val_loss: 0.7484 - val_accuracy: 0.7858 - lr: 1.3422e-04
# Epoch 102/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6639 - accuracy: 0.8098 - val_loss: 0.7076 - val_accuracy: 0.8049 - lr: 1.3422e-04
# Epoch 103/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.6650 - accuracy: 0.8092 - val_loss: 0.7674 - val_accuracy: 0.7898 - lr: 1.3422e-04
# Epoch 104/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6644 - accuracy: 0.8070 - val_loss: 0.7262 - val_accuracy: 0.7938 - lr: 1.3422e-04
# Epoch 105/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6484 - accuracy: 0.8108 - val_loss: 0.6984 - val_accuracy: 0.8038 - lr: 1.0737e-04
# Epoch 106/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6437 - accuracy: 0.8113 - val_loss: 0.6844 - val_accuracy: 0.8042 - lr: 1.0737e-04
# Epoch 107/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6456 - accuracy: 0.8114 - val_loss: 0.7114 - val_accuracy: 0.7893 - lr: 1.0737e-04
# Epoch 108/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6437 - accuracy: 0.8120 - val_loss: 0.7225 - val_accuracy: 0.7969 - lr: 1.0737e-04
# Epoch 109/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6442 - accuracy: 0.8123 - val_loss: 0.7202 - val_accuracy: 0.7964 - lr: 1.0737e-04
# Epoch 110/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6443 - accuracy: 0.8140 - val_loss: 0.7512 - val_accuracy: 0.7864 - lr: 1.0737e-04
# Epoch 111/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6446 - accuracy: 0.8119 - val_loss: 0.6930 - val_accuracy: 0.7967 - lr: 1.0737e-04
# Epoch 112/125
# 1407/1407 [==============================] - 44s 32ms/step - loss: 0.6311 - accuracy: 0.8116 - val_loss: 0.6791 - val_accuracy: 0.8007 - lr: 8.5899e-05
# Epoch 113/125
# 1407/1407 [==============================] - 44s 32ms/step - loss: 0.6303 - accuracy: 0.8133 - val_loss: 0.6971 - val_accuracy: 0.7996 - lr: 8.5899e-05
# Epoch 114/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.6303 - accuracy: 0.8146 - val_loss: 0.7071 - val_accuracy: 0.7993 - lr: 8.5899e-05
# Epoch 115/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.6264 - accuracy: 0.8128 - val_loss: 0.7179 - val_accuracy: 0.7967 - lr: 8.5899e-05
# Epoch 116/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.6284 - accuracy: 0.8135 - val_loss: 0.6868 - val_accuracy: 0.7987 - lr: 8.5899e-05
# Epoch 117/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6282 - accuracy: 0.8134 - val_loss: 0.6774 - val_accuracy: 0.8047 - lr: 8.5899e-05
# Epoch 118/125
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.6286 - accuracy: 0.8117 - val_loss: 0.7074 - val_accuracy: 0.7980 - lr: 8.5899e-05
# Epoch 119/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6299 - accuracy: 0.8129 - val_loss: 0.6831 - val_accuracy: 0.8067 - lr: 8.5899e-05
# Epoch 120/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6223 - accuracy: 0.8161 - val_loss: 0.6712 - val_accuracy: 0.8018 - lr: 8.5899e-05
# Epoch 121/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6260 - accuracy: 0.8152 - val_loss: 0.6883 - val_accuracy: 0.8049 - lr: 8.5899e-05
# Epoch 122/125
# 1407/1407 [==============================] - 44s 32ms/step - loss: 0.6267 - accuracy: 0.8154 - val_loss: 0.6584 - val_accuracy: 0.8131 - lr: 8.5899e-05
# Epoch 123/125
# 1407/1407 [==============================] - 46s 32ms/step - loss: 0.6265 - accuracy: 0.8115 - val_loss: 0.7285 - val_accuracy: 0.7902 - lr: 8.5899e-05
# Epoch 124/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6249 - accuracy: 0.8158 - val_loss: 0.6991 - val_accuracy: 0.7969 - lr: 8.5899e-05
# Epoch 125/125
# 1407/1407 [==============================] - 44s 31ms/step - loss: 0.6241 - accuracy: 0.8136 - val_loss: 0.6663 - val_accuracy: 0.8116 - lr: 8.5899e-05

# %% [markdown]
# We will plot the loss and accuracy for the training and validation data sets.

# %%
print(history.history.keys())
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# # 6. Model Testing
# We will iterate through the test data and analyse the results using tools from sklearn. We create a classification report, a confusion matrix and also plot a few examples from the test set.

# %% [markdown]
# Iterate through n_test batches and store the predicted and ground truth labels in numpy arrays.

# %%
n_test = 100 # number of batches to use
store_predictions = []
store_labels = []
for image_batch,label_batch in test_dataset.take(n_test):
    predictions = model.predict_on_batch(image_batch) 
    predictions = tf.math.argmax(predictions,axis=1)
    store_predictions.append(predictions)
    store_labels.append(label_batch)
y_pred = np.squeeze(np.reshape(store_predictions,(1,n_test*batch_size)))
y_true = np.squeeze(np.reshape(store_labels,(1,n_test*batch_size)))

# %% [markdown]
# Create and plot a confusion matrix.

# %%
#https://scikit-learn.org/0.16/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_str))
    plt.xticks(tick_marks, label_str, rotation=45)
    plt.yticks(tick_marks, label_str)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm)

# %% [markdown]
# Generate & print the classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=label_str))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.84      0.83      0.84       337
#   automobile       0.89      0.92      0.91       338
#         bird       0.77      0.69      0.73       306
#          cat       0.61      0.72      0.66       323
#         deer       0.77      0.80      0.79       297
#          dog       0.78      0.70      0.74       325
#         frog       0.94      0.78      0.85       307
#        horse       0.84      0.88      0.86       317
#         ship       0.90      0.90      0.90       326
#        truck       0.83      0.88      0.86       324
#
#     accuracy                           0.81      3200
#    macro avg       0.82      0.81      0.81      3200
# weighted avg       0.82      0.81      0.81      3200

# %% [markdown]
# Plot some test images and predicted labels.

# %%
#Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)
print(np.shape(predictions))
# Apply a sigmoid since our model returns logits
predictions = tf.math.argmax(predictions,axis=1)
print(np.shape(predictions))
print('Predictions:\n', predictions.numpy())


i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image in image_batch[0:n_plots,:,:,:]:  # Only take a single example
  axarr[i].imshow(image[:,:,:]+0.5)
  axarr[i].axis('off')
  
  color = ('black' if predictions[i] == int(label_batch[i]) else 'red') 
  axarr[i].set_title(label_str[int(predictions[i])],fontsize='small', color=color)
  i = i+1
# Out:
# (32, 10)
# (32,)
# Predictions:
#  [7 0 6 9 7 1 7 0 3 2 7 2 7 9 2 9 0 8 7 9 4 5 3 5 0 0 2 8 9 8 2 0]

# %% [markdown]
# # Please Leave a note here explaining your approach/results for the e-moderator.

# %% [markdown]
# ## Approach outline
#
# The approach taken here was to focus on building the Resnet architecture that is known to perform well due to its shortcut structure.
#
# The ResNet consists of stacked layers of convolvutions, activations and batch normalizations applied to the input, that get added to the input on a shortcut path. [Veit(2016)](https://arxiv.org/pdf/1605.06431.pdf) explains that they behave like Shallow networks and therefore are easier to train compared to a VGG style architecture. The shortened effective paths avoids vanishing gradients. Batch normalization is also introduced and the a familiar pattern starts to emerge of Convolution -> Activation ReLU -> Batch normalization.
#
# In this approach I started off with adding a Residual block function called `resnetblock` that calls the `repeat_unit` 3 times before creating a shortcut path to the input.
#
# I also added a Pooling layer, to reduce the output and number of operations before the FullyConnected dense layer that would take up the most memory.
#
# Other things I tweaked after interacting in the forum and reading suggestions from others were:
#  - Batch size = 256 (suggested by Nigel Portley). This vastyly increased training times.
#  - Added data augmentation; added RandomFlips, RandomTranslations and RandomZooms of +- 10%.
#  - Added 2 callbacks (adjustments during the training process):
#   - Adjust learning rate if `val_loss` plateaus for 5 epochs in a row
#   - Early stop if `loss` doesn't stop improve for 5 epochs in a row.
# - Adding dropout did not seem to improve accuracy at all.
# - Adding l1 regalurization worked to try reduce overfitting in the later epochs.
#
# ## Results
# Validation accuracy of X% was achieved
#
#
# ## Further improvements
# Main one would be to use cloud resources decrease training times for the models.
